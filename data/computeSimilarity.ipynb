# %% [markdown]
# # DMH artwork
#
# A set of N artworks from Design Museum Helsinki. The dataset was created in the contexto of the [SPICE project](https://spice-h2020.eu/)

# %%
import json
  
# Opening JSON file
with open('./DMH/items.json') as f:
    dataFile = json.load(f)
data = dataFile["data"]
data
# Out:
# [{'_id': '634f19096c70ef5cf152f237',
#   'title': 'Scandia',
#   'Object': 'CUTLERY',
#   'Special name': '*',
#   'id': '44171',
#   'author': 'Franck, Kaj',
#   'Production date': '1952',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Hackman Sorsakoski',
#   'Dimension in cm': 'fork: 17.5 cm (length) x 0.15cm (thickness)  knife: 18.6 cm (length) x 0.3/0.15 cm (thickness)  spoon: 18 cm (length)',
#   'Weight in kg': '*',
#   'Materials': ['metal'],
#   'Colour': ['metal'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1668599056,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 11,
#   '_timestamp_day': 16,
#   '_timestamp_hour': 11,
#   '_timestamp_minute': 44,
#   '_timestamp_second': 16,
#   '_updated': 1.0,
#   'year': 1952.0,
#   'ColourRGB': [[109, 114, 120]],
#   'image': 'https://i.postimg.cc/Zqn1M35m/44171.png',
#   'Object group': 'cutlery',
#   'Color': [{'colorName': 'metal', 'rgb': [109, 114, 120]}]},
#  {'_id': '634f1908b7693f159a62e2f6',
#   'title': 'Savonia',
#   'Object': 'CUTLERY',
#   'Special name': '*',
#   'id': '44168',
#   'author': 'Babel, Adolf',
#   'Production date': '1967',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Hackman Sorsakoski',
#   'Dimension in cm': 'fork: 19.5 cm (length) x 0.1 cm (thickness)  knife: 19 cm (length) x   0.1 cm (thickness)',
#   'Weight in kg': '*',
#   'Materials': ['metal'],
#   'Colour': ['metal'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1668598994,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 11,
#   '_timestamp_day': 16,
#   '_timestamp_hour': 11,
#   '_timestamp_minute': 43,
#   '_timestamp_second': 14,
#   '_updated': 1.0,
#   'year': 1967.0,
#   'ColourRGB': [[109, 114, 120]],
#   'image': 'https://i.postimg.cc/65NxpyYV/44168.png',
#   'Object group': 'cutlery',
#   'Color': [{'colorName': 'metal', 'rgb': [109, 114, 120]}]},
#  {'_id': '636bf322a8e46b2e35302848',
#   'title': 'Ultima Thule 2332',
#   'Object': 'BOWL',
#   'Special name': 'fruit or dessert bowl',
#   'id': '14219',
#   'author': 'Wirkkala, Tapio',
#   'Production date': '1970',
#   'Collection': '*',
#   'Manufacturer': 'A AhlstrÃ¶m Oy, Iitalan lasitehdas',
#   'Dimension in cm': '20x20x9',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['colourless glass'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1668018978,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 11,
#   '_timestamp_day': 9,
#   '_timestamp_hour': 18,
#   '_timestamp_minute': 36,
#   '_timestamp_second': 18,
#   '_updated': None,
#   'year': 1970.0,
#   'ColourRGB': [],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-017298_wirkkala_ultima_thule-2000x1621.jpg',
#   'Object group': 'glass',
#   'Color': []},
#  {'_id': '634f1907d8af1b50664089d0',
#   'title': 'Japanese teapot',
#   'Object': 'JUG',
#   'Special name': 'teapot',
#   'id': 'B561',
#   'author': '*',
#   'Production date': '19th century',
#   'Collection': 'Antell',
#   'Manufacturer': '*',
#   'Dimension in cm': '16,8 x 14 x 15',
#   'Weight in kg': '*',
#   'Materials': ['stoneware'],
#   'Colour': ['light brown', 'dark brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128834,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 33,
#   '_timestamp_second': 54,
#   '_updated': 1.0,
#   'year': None,
#   'ColourRGB': [[165, 42, 42], [92, 64, 51]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-b561-2000x1500.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'light brown', 'rgb': [165, 42, 42]},
#    {'colorName': 'dark brown', 'rgb': [92, 64, 51]}]},
#  {'_id': '634f1903a45b33465c10ceb2',
#   'title': 'Windbreaker',
#   'Object': 'JACKET',
#   'Special name': 'Jacket',
#   'id': '44166',
#   'author': 'Kellokumpu, Ritva',
#   'Production date': '1984',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Torstai',
#   'Dimension in cm': '*',
#   'Weight in kg': '*',
#   'Materials': ['polyesterivanu'],
#   'Colour': ['orange', ' green', ' blue', ' pink'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128709,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 31,
#   '_timestamp_second': 49,
#   '_updated': 1.0,
#   'year': 1984.0,
#   'ColourRGB': [[255, 165, 0], [0, 128, 0], [0, 0, 255], [255, 192, 203]],
#   'image': 'https://i.postimg.cc/bNHcDpB7/44166.jpg',
#   'Object group': 'clothes and accessories',
#   'Color': [{'colorName': 'orange', 'rgb': [255, 165, 0]},
#    {'colorName': ' green', 'rgb': [0, 128, 0]},
#    {'colorName': ' blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' pink', 'rgb': [255, 192, 203]}]},
#  {'_id': '634f1912d8af1b50664089d6',
#   'title': 'Rautaristi (Iron Cross)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '16850',
#   'author': 'KeinÃ¤nen-Baeckmann, Aino',
#   'Production date': '1931',
#   'Collection': '*',
#   'Manufacturer': 'Oy Neovius Ab',
#   'Dimension in cm': '145 cm x 100 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool', 'cotton'],
#   'Colour': ['violet', ' yellowish'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128146,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 26,
#   '_updated': None,
#   'year': 1931.0,
#   'ColourRGB': [[238, 130, 238], [255, 255, 0]],
#   'image': 'https://i.postimg.cc/ZqDhbHM0/16850.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'violet', 'rgb': [238, 130, 238]},
#    {'colorName': ' yellowish', 'rgb': [255, 255, 0]}]},
#  {'_id': '634f1912e09bfd1d9a04b8f9',
#   'title': 'Valkoiset hevoset (White Horses)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '13906',
#   'author': 'Sotavalta, Impi',
#   'Production date': '1932',
#   'Collection': '*',
#   'Manufacturer': 'HumalajÃ¤rvi, Kerttu',
#   'Dimension in cm': '173 cm x 126 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool', 'cotton'],
#   'Colour': ['white', ' red', ' brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128146,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 26,
#   '_updated': None,
#   'year': 1932.0,
#   'ColourRGB': [[255, 255, 255], [255, 0, 0], [165, 42, 42]],
#   'image': 'https://i.postimg.cc/mgB48t9Z/13906.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]},
#    {'colorName': ' red', 'rgb': [255, 0, 0]},
#    {'colorName': ' brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f1912d4227a56290cb6d2',
#   'title': 'Liekki (Flame)',
#   'Object': 'WALL TEXTILE, ART TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '17876',
#   'author': 'Gallen-Kallela, Akseli',
#   'Production date': '1899',
#   'Collection': '*',
#   'Manufacturer': 'Suomen KÃ¤sityÃ¶n ystÃ¤vÃ¤t /  Asikainen, Ann-Mari ja Lindberg, Merja',
#   'Dimension in cm': '175 cm x 250 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool', 'cotton'],
#   'Colour': [],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128146,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 26,
#   '_updated': None,
#   'year': 1899.0,
#   'ColourRGB': [],
#   'image': 'https://i.postimg.cc/fWdhsxjT/17876.jpg',
#   'Object group': 'wall textiles',
#   'Color': []},
#  {'_id': '634f1911d28967637e31c912',
#   'title': 'Neljä väriä (Four Colours)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '32628',
#   'author': 'Simberg-EhrstrÃ¶m, Uhra',
#   'Production date': '1958',
#   'Collection': 'OpetusministeriÃ¶n ryijykokoelma',
#   'Manufacturer': 'Suomen KÃ¤sityÃ¶n YstÃ¤vÃ¤t /  Sillfors, Pirkko',
#   'Dimension in cm': '180 cm x 119 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool'],
#   'Colour': [],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128145,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 25,
#   '_updated': None,
#   'year': 1958.0,
#   'ColourRGB': [],
#   'image': 'https://i.postimg.cc/d3GM9YtT/32628.jpg',
#   'Object group': 'wall textiles',
#   'Color': []},
#  {'_id': '634f1911a45b33465c10ceba',
#   'title': 'Seebra (Zebra)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '32627',
#   'author': 'Brummer, Eva',
#   'Production date': '1951',
#   'Collection': 'OpetusministeriÃ¶n ryijykokoelma',
#   'Manufacturer': 'Suomen KÃ¤sityÃ¶n YstÃ¤vÃ¤t /  Ahlblad, Margit',
#   'Dimension in cm': '178 cm x 118 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool', 'cotton'],
#   'Colour': ['black', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128145,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 25,
#   '_updated': None,
#   'year': 1951.0,
#   'ColourRGB': [[0, 0, 0], [255, 255, 255]],
#   'image': 'https://i.postimg.cc/GmL0v60H/32627.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'black', 'rgb': [0, 0, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f19119d480d2bcc4ac7ac',
#   'title': 'Suopursuja (Marsh Tea)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '16851',
#   'author': 'Raitio, A. W.',
#   'Production date': '1934',
#   'Collection': '*',
#   'Manufacturer': 'Oy Neovius Ab',
#   'Dimension in cm': '89 cm x 137 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool', 'cotton'],
#   'Colour': ['brown', ' light pastel shade'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128145,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 25,
#   '_updated': None,
#   'year': 1934.0,
#   'ColourRGB': [[165, 42, 42]],
#   'image': 'https://i.postimg.cc/rppk23gv/16851.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f19106c70ef5cf152f23b',
#   'title': 'Raitakaita',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44184',
#   'author': 'LeppÃ¤nen, Helena',
#   'Production date': '2001',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Hackman Designor',
#   'Dimension in cm': '*',
#   'Weight in kg': '*',
#   'Materials': ['porcelain'],
#   'Colour': ['blue', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128144,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 24,
#   '_updated': None,
#   'year': 2001.0,
#   'ColourRGB': [[0, 0, 255], [255, 255, 255]],
#   'image': 'https://i.postimg.cc/HLFPvhN0/44184.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f19105350725cb83093c4',
#   'title': 'Suo (Marsh)',
#   'Object': 'WALL TEXTILE',
#   'Special name': 'ryijy rug',
#   'id': '32361',
#   'author': 'Puotila, Ritva',
#   'Production date': '1975',
#   'Collection': 'OpetusministeriÃ¶n ryijykokoelma',
#   'Manufacturer': 'Suomen KÃ¤sityÃ¶n YstÃ¤vÃ¤t /  Hartikainen, Anneli',
#   'Dimension in cm': '174 cm x 133 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool'],
#   'Colour': ['different tones of red brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128144,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 24,
#   '_updated': None,
#   'year': 1975.0,
#   'ColourRGB': [[165, 42, 42]],
#   'image': 'https://i.postimg.cc/d0fzP1hy/32361.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'different tones of red brown',
#     'rgb': [165, 42, 42]}]},
#  {'_id': '634f191005fdc719f0345aef',
#   'title': 'Simpukka (Sea Shell)',
#   'Object': 'RUG',
#   'Special name': 'rug',
#   'id': '33288',
#   'author': 'Metsovaara, Marjatta',
#   'Production date': '1962',
#   'Collection': '*',
#   'Manufacturer': 'Oy Finnrya Ab',
#   'Dimension in cm': '167,5 cm x 134 cm',
#   'Weight in kg': '*',
#   'Materials': ['wool'],
#   'Colour': ['red', ' aniline', ' yellow'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128144,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 24,
#   '_updated': None,
#   'year': 1962.0,
#   'ColourRGB': [[255, 0, 0], [255, 255, 0], [255, 255, 0]],
#   'image': 'https://i.postimg.cc/zG0s7p5p/33288.jpg',
#   'Object group': 'wall textiles',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]},
#    {'colorName': ' aniline', 'rgb': [255, 255, 0]},
#    {'colorName': ' yellow', 'rgb': [255, 255, 0]}]},
#  {'_id': '634f190fe09bfd1d9a04b8f7',
#   'title': 'Flora (model S)',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44181',
#   'author': 'ProcopÃ©, Ulla  Tomula, Esteri',
#   'Production date': '1978',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': 'cup: 10 cm (diameter) x 5,5 cm (height)  saucer: 16,3 cm (diameter) x 2 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['blue', ' green', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128143,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 23,
#   '_updated': None,
#   'year': 1978.0,
#   'ColourRGB': [[0, 0, 255], [0, 128, 0], [255, 255, 255]],
#   'image': 'https://i.postimg.cc/kgXZ288S/44181.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' green', 'rgb': [0, 128, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190fd4227a56290cb6d0',
#   'title': 'Think and drink',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44182',
#   'author': 'Rintaniemi, PÃ¤ivi',
#   'Production date': '1998',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Amfora',
#   'Dimension in cm': 'cup: 5,5 cm (diameter) x 6 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['yellow', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128143,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 23,
#   '_updated': None,
#   'year': 1998.0,
#   'ColourRGB': [[255, 255, 0], [255, 255, 255]],
#   'image': 'https://i.postimg.cc/nhRWBzYP/44182.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'yellow', 'rgb': [255, 255, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190fb7693f159a62e2fa',
#   'title': 'Warm',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44183',
#   'author': 'AlfstrÃ¶m, Tony,  Keaney, Brian',
#   'Production date': '1998',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Tonfisk',
#   'Dimension in cm': '8 cm (diameter) x 9.6 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics', 'wood'],
#   'Colour': ['white', ' wood'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128143,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 23,
#   '_updated': None,
#   'year': 1998.0,
#   'ColourRGB': [[255, 255, 255], [186, 140, 99]],
#   'image': 'https://i.postimg.cc/jjDFXbMd/44183.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]},
#    {'colorName': ' wood', 'rgb': [186, 140, 99]}]},
#  {'_id': '634f190ea45b33465c10ceb8',
#   'title': 'Teema (model BAU)',
#   'Object': 'MUG',
#   'Special name': '*',
#   'id': '44178',
#   'author': 'Franck, Kaj',
#   'Production date': '1981',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': 'cup: 7.2/6.4cm (base diameter / top diameter) x 5.5 cm (height)  saucer: 14.3 cm (diameter) x 2.4 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128142,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 22,
#   '_updated': None,
#   'year': 1981.0,
#   'ColourRGB': [[255, 255, 255]],
#   'image': 'https://i.postimg.cc/XNdtmn4r/44178.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190e9d480d2bcc4ac7aa',
#   'title': 'Ruska (model S)',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44179',
#   'author': 'ProcopÃ©, Ulla',
#   'Production date': '1960',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': 'cup: 7cm (diameter) x 7,8cm (height)  saucer: 12,6cm (diameter) x 2cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128142,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 22,
#   '_updated': None,
#   'year': 1960.0,
#   'ColourRGB': [[165, 42, 42]],
#   'image': 'https://i.postimg.cc/CL09V9xm/44179.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f190ed8af1b50664089d4',
#   'title': 'Katrilli',
#   'Object': 'MUG',
#   'Special name': '*',
#   'id': '44180',
#   'author': 'Tarna, Tauno',
#   'Production date': '1969',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Sarvis Oy',
#   'Dimension in cm': 'cup: 7 cm (diameter) x   7 cm (height)  saucer: d x h:14cm x 2cm',
#   'Weight in kg': '*',
#   'Materials': ['plastic'],
#   'Colour': ['brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128142,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 22,
#   '_updated': None,
#   'year': 1969.0,
#   'ColourRGB': [[165, 42, 42]],
#   'image': 'https://i.postimg.cc/jdhmqvWK/44180.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f190d5350725cb83093c2',
#   'title': 'Iris (model U2)',
#   'Object': 'MUG',
#   'Special name': '*',
#   'id': '44175',
#   'author': 'Finch, Alfred William',
#   'Production date': '1898-1902',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Ab Iris Oy',
#   'Dimension in cm': '10 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['brown', ' blue', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128141,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 21,
#   '_updated': None,
#   'year': 1900.0,
#   'ColourRGB': [[165, 42, 42], [0, 0, 255], [255, 255, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/08/wsi-imageoptim-b548-2000x2665.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]},
#    {'colorName': ' blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190d05fdc719f0345aed',
#   'title': 'Myrna (malli AX)',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44176',
#   'author': 'Osol, Olga',
#   'Production date': '1937',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': 'cup: 8.4/4.1 cm (diameter) x 6.2 cm (height)  saucer: 13 cm (diameter) x 1.8 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['white', ' brown', ' gold'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128141,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 21,
#   '_updated': None,
#   'year': 1937.0,
#   'ColourRGB': [[255, 255, 255], [165, 42, 42], [255, 215, 0]],
#   'image': 'https://i.postimg.cc/2yQJZ72Q/44176.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]},
#    {'colorName': ' brown', 'rgb': [165, 42, 42]},
#    {'colorName': ' gold', 'rgb': [255, 215, 0]}]},
#  {'_id': '634f190dd28967637e31c910',
#   'title': 'Rice porcelain cup (model FK/VA)',
#   'Object': 'COFFEE CUP',
#   'Special name': '*',
#   'id': '44177',
#   'author': 'Holzer-Kjellberg, Friedl',
#   'Production date': '1945',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': 'cup: 6/4.2 cm (diameter) x 7.7 cm (height)  saucer: 12.5 cm (diameter) x 2 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['ceramics'],
#   'Colour': ['white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128141,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 21,
#   '_updated': None,
#   'year': 1945.0,
#   'ColourRGB': [[255, 255, 255]],
#   'image': 'https://i.postimg.cc/J0Vv02c7/44177.png',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190cd4227a56290cb6ce',
#   'title': 'i-102 (Aroma 2002)',
#   'Object': 'DRINKING GLASS',
#   'Special name': 'aroma glass',
#   'id': '7762',
#   'author': 'Sarpaneva, Timo',
#   'Production date': '1956',
#   'Collection': '*',
#   'Manufacturer': 'Iittala',
#   'Dimension in cm': '5,5 cm (diameter) x 7 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['green gray'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128140,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 20,
#   '_updated': None,
#   'year': 1956.0,
#   'ColourRGB': [[114, 131, 112]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-025419-2000x1333.jpg',
#   'Object group': 'glass',
#   'Color': [{'colorName': 'green gray', 'rgb': [114, 131, 112]}]},
#  {'_id': '634f190cb7693f159a62e2f8',
#   'title': 'I-lasi 2004',
#   'Object': 'DRINKING GLASS',
#   'Special name': '*',
#   'id': 'ILM7606',
#   'author': 'Sarpaneva, Timo',
#   'Production date': '1956',
#   'Collection': '*',
#   'Manufacturer': 'Iittala',
#   'Dimension in cm': '3,5 cm (base diameter) x 5 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['blue', ' violet'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128140,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 20,
#   '_updated': None,
#   'year': 1956.0,
#   'ColourRGB': [[0, 0, 255], [238, 130, 238]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-025419-2000x1333.jpg',
#   'Object group': 'glass',
#   'Color': [{'colorName': 'blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' violet', 'rgb': [238, 130, 238]}]},
#  {'_id': '634f190c6c70ef5cf152f239',
#   'title': 'Ultima Thule (18 cl)',
#   'Object': 'DRINKING GLASS',
#   'Special name': 'cocktail glass',
#   'id': '14218',
#   'author': 'Wirkkala, Tapio',
#   'Production date': '1968',
#   'Collection': '*',
#   'Manufacturer': 'A AhlstrÃ¶m Oy, Iittalan lasitehdas',
#   'Dimension in cm': '8,6 x 8,6 x 10,4',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['colourless glass'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128140,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 20,
#   '_updated': None,
#   'year': 1968.0,
#   'ColourRGB': [],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-017298_wirkkala_ultima_thule-2000x1621.jpg',
#   'Object group': 'glass',
#   'Color': []},
#  {'_id': '634f190b9d480d2bcc4ac7a8',
#   'title': '1718',
#   'Object': 'GLASS',
#   'Special name': 'stackable drinking glass',
#   'id': '10026',
#   'author': 'Hopea, Saara',
#   'Production date': '1954',
#   'Collection': '*',
#   'Manufacturer': 'NuutajÃ¤rven lasi',
#   'Dimension in cm': '7 cm (diameter) x 8,5 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['red'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128139,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 19,
#   '_updated': None,
#   'year': 1954.0,
#   'ColourRGB': [[255, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-dmpm_20150103_2785-2000x3000.jpg',
#   'Object group': 'glass',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]}]},
#  {'_id': '634f190bd8af1b50664089d2',
#   'title': '2744 cocktail glass',
#   'Object': 'GLASS',
#   'Special name': 'drinking glass',
#   'id': '12595',
#   'author': 'Franck, Kaj',
#   'Production date': '1953',
#   'Collection': '*',
#   'Manufacturer': 'NuutajÃ¤rven lasi',
#   'Dimension in cm': '8 cm (diameter) x 8 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['rubin red'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128139,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 19,
#   '_updated': None,
#   'year': 1953.0,
#   'ColourRGB': [[224, 17, 95]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-025608__franck_p-1-1327x1823.jpg',
#   'Object group': 'glass',
#   'Color': [{'colorName': 'rubin red', 'rgb': [224, 17, 95]}]},
#  {'_id': '634f190be09bfd1d9a04b8f5',
#   'title': '1610',
#   'Object': 'JUG',
#   'Special name': 'cocktail mixer',
#   'id': '22769',
#   'author': 'Franck, Kaj',
#   'Production date': '1954',
#   'Collection': '*',
#   'Manufacturer': 'NuutajÃ¤rven lasi',
#   'Dimension in cm': '10 cm x 22 cm (heigtht)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['red', ' purple'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128139,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 19,
#   '_updated': None,
#   'year': 1954.0,
#   'ColourRGB': [[255, 0, 0], [128, 0, 128]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-franck-1610-lh-1667x2379.jpeg',
#   'Object group': 'jugs',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]},
#    {'colorName': ' purple', 'rgb': [128, 0, 128]}]},
#  {'_id': '634f190905fdc719f0345aeb',
#   'title': 'MK',
#   'Object': 'CREAMER',
#   'Special name': 'cream bottle',
#   'id': 'AM1699',
#   'author': 'Franck, Kaj',
#   'Production date': '1948',
#   'Collection': '*',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': '65 mm (base diameter) x 135 mm (heigtht with lid)',
#   'Weight in kg': '*',
#   'Materials': ['porcelain'],
#   'Colour': ['white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128138,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 18,
#   '_updated': None,
#   'year': 1948.0,
#   'ColourRGB': [[255, 255, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/05/kermakko-mk-am1699-320x320.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190ad28967637e31c90e',
#   'title': 'BAU, Muumi',
#   'Object': 'MUG',
#   'Special name': 'mug',
#   'id': '44185',
#   'author': 'Jansson, Tove  Franck, Kaj  Slotte-Elevant, Tove (decoration)',
#   'Production date': '1979-1980 (model), 1990-1991 (decoration)',
#   'Collection': '*',
#   'Manufacturer': 'Arabia',
#   'Dimension in cm': '8 cm (height)',
#   'Weight in kg': '*',
#   'Materials': ['stoneware'],
#   'Colour': ['gray', ' black', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128138,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 18,
#   '_updated': None,
#   'year': 1984.0,
#   'ColourRGB': [[128, 128, 128], [0, 0, 0], [255, 255, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/09/wsi-imageoptim-muumi1-2000x2666.jpg',
#   'Object group': 'cups',
#   'Color': [{'colorName': 'gray', 'rgb': [128, 128, 128]},
#    {'colorName': ' black', 'rgb': [0, 0, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f190aa45b33465c10ceb6',
#   'title': '1618',
#   'Object': 'JUG',
#   'Special name': 'jug of a stackable glass set',
#   'id': 'A652',
#   'author': 'Hopea, Saara',
#   'Production date': '1950s',
#   'Collection': '*',
#   'Manufacturer': 'NuutajÃ¤rven lasi',
#   'Dimension in cm': '10.5 (diameter) x 16 (height)',
#   'Weight in kg': '*',
#   'Materials': ['glass'],
#   'Colour': ['clear'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128138,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 18,
#   '_updated': None,
#   'year': 1950.0,
#   'ColourRGB': [],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-dmpm_20150103_2785-2000x3000.jpg',
#   'Object group': 'jugs',
#   'Color': []},
#  {'_id': '634f19095350725cb83093c0',
#   'title': 'Fiskars scissors',
#   'Object': 'SCISSORS',
#   'Special name': '*',
#   'id': '44174',
#   'author': 'BÃ¤ckstrÃ¶m, Olof,  LindÃ©n, Olavi',
#   'Production date': '1967',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Fiskars',
#   'Dimension in cm': '21 cm (length)',
#   'Weight in kg': '*',
#   'Materials': ['plastic', 'metal'],
#   'Colour': ['orange'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128137,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 17,
#   '_updated': None,
#   'year': 1967.0,
#   'ColourRGB': [[255, 165, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/01/wsi-imageoptim-img656-1667x2181.jpg',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'orange', 'rgb': [255, 165, 0]}]},
#  {'_id': '634f1908e09bfd1d9a04b8f3',
#   'title': 'Pehtoori 2615',
#   'Object': 'POT',
#   'Special name': 'coffee pot',
#   'id': '8182',
#   'author': 'Nurmesniemi, Antti',
#   'Production date': '1957',
#   'Collection': '*',
#   'Manufacturer': 'WÃ¤rtsilÃ¤ Oyj Abp, JÃ¤rvenpÃ¤Ã¤n emali',
#   'Dimension in cm': '1.5 x 1.65 (diameter of base x height without lid)',
#   'Weight in kg': '*',
#   'Materials': ['metal', 'enamel', 'melamine'],
#   'Colour': ['red', ' black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128136,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 16,
#   '_updated': None,
#   'year': 1957.0,
#   'ColourRGB': [[255, 0, 0], [0, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-025478_anurmesniemi_pehtoori_rt-1327x1990.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]},
#    {'colorName': ' black', 'rgb': [0, 0, 0]}]},
#  {'_id': '634f1908d4227a56290cb6cc',
#   'title': 'Cast Iron Pot',
#   'Object': 'CASSEROLE',
#   'Special name': 'cast iron casserole with a lid',
#   'id': 'C370',
#   'author': 'Sarpaneva, Timo',
#   'Production date': '1960',
#   'Collection': '*',
#   'Manufacturer': 'W. Rosenlew & Co, Porin konepaja',
#   'Dimension in cm': '21.9 x 21.9 x 17.75',
#   'Weight in kg': '4,918',
#   'Materials': ['castiron', 'teak'],
#   'Colour': ['black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128136,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 16,
#   '_updated': None,
#   'year': 1960.0,
#   'ColourRGB': [[0, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-32712-2000x2667.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'black', 'rgb': [0, 0, 0]}]},
#  {'_id': '634f1907a45b33465c10ceb4',
#   'title': 'Subway bench',
#   'Object': 'SEAT',
#   'Special name': 'bench',
#   'id': '41816',
#   'author': 'Rajalin, BÃ¶rje,  Nurmesniemi, Antti',
#   'Production date': '1979',
#   'Collection': '*',
#   'Manufacturer': 'Artekno Oy',
#   'Dimension in cm': None,
#   'Weight in kg': '*',
#   'Materials': ['fiberglass'],
#   'Colour': ['orange'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128135,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 15,
#   '_updated': None,
#   'year': 1979.0,
#   'ColourRGB': [[255, 165, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/09/wsi-imageoptim-metro-41816-899x477.jpg',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'orange', 'rgb': [255, 165, 0]}]},
#  {'_id': '634f19079d480d2bcc4ac7a6',
#   'title': 'Garbage Bin',
#   'Object': 'GARBAGE BIN',
#   'Special name': '*',
#   'id': '44167',
#   'author': 'Creadesign Oy,   KÃ¤hÃ¶nen, Hannu',
#   'Production date': '1989-1990',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'SÃ¤kkivÃ¤line company',
#   'Dimension in cm': '31,5x31,5x58',
#   'Weight in kg': '14',
#   'Materials': ['metal'],
#   'Colour': ['metal'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128135,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 15,
#   '_updated': None,
#   'year': 1989.0,
#   'ColourRGB': [[109, 114, 120]],
#   'image': '',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'metal', 'rgb': [109, 114, 120]}]},
#  {'_id': '634f19065350725cb83093be',
#   'title': 'Jopo',
#   'Object': 'BICYCLE',
#   'Special name': '*',
#   'id': '11780',
#   'author': 'Hellman,   Rislakki, Eero (colours)',
#   'Production date': 'n. 1965, 1979',
#   'Collection': '*',
#   'Manufacturer': 'Helkama',
#   'Dimension in cm': '45 cm (frame)',
#   'Weight in kg': '14,9',
#   'Materials': ['metal'],
#   'Colour': ['green', ' black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128134,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 14,
#   '_updated': None,
#   'year': 1972.0,
#   'ColourRGB': [[0, 128, 0], [0, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-img_3604-2000x1958.jpg',
#   'Object group': 'vehicles',
#   'Color': [{'colorName': 'green', 'rgb': [0, 128, 0]},
#    {'colorName': ' black', 'rgb': [0, 0, 0]}]},
#  {'_id': '634f190605fdc719f0345ae9',
#   'title': 'Solifer Export',
#   'Object': 'LIGHT MOTORCYCLE',
#   'Special name': 'moped',
#   'id': '32271',
#   'author': 'Lindh, Richard',
#   'Production date': '1960',
#   'Collection': '*',
#   'Manufacturer': 'Wilh Bensow Oy',
#   'Dimension in cm': '185 x 76 x 101',
#   'Weight in kg': '45',
#   'Materials': ['metal', 'leather'],
#   'Colour': ['blue', ' white', ' red', ' black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128134,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 14,
#   '_updated': None,
#   'year': 1960.0,
#   'ColourRGB': [[0, 0, 255], [255, 255, 255], [255, 0, 0], [0, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-1210201010051517_richard_lindh_solifer_export_1960_suomi_017667-compressor-2000x1297.jpg',
#   'Object group': 'vehicles',
#   'Color': [{'colorName': 'blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]},
#    {'colorName': ' red', 'rgb': [255, 0, 0]},
#    {'colorName': ' black', 'rgb': [0, 0, 0]}]},
#  {'_id': '634f1906d28967637e31c90c',
#   'title': 'Jerry',
#   'Object': 'CANISTER, CONTAINER',
#   'Special name': 'petrol canister',
#   'id': '32030',
#   'author': 'Rislakki, Eero',
#   'Production date': '1971',
#   'Collection': '*',
#   'Manufacturer': 'HuhtamÃ¤ki Oyj, PyrkijÃ¤ Oy',
#   'Dimension in cm': '24 x 17 x 35',
#   'Weight in kg': '*',
#   'Materials': ['plastic'],
#   'Colour': ['red'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128134,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 14,
#   '_updated': None,
#   'year': 1971.0,
#   'ColourRGB': [[255, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/09/wsi-imageoptim-32030-2000x2667.jpg',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]}]},
#  {'_id': '634f1905d4227a56290cb6ca',
#   'title': 'Mobira Talkman 450',
#   'Object': 'TELEPHONE',
#   'Special name': 'portable phone',
#   'id': '41379',
#   'author': 'Pitkonen, Jorma',
#   'Production date': '1984 â€“ 1986',
#   'Collection': '*',
#   'Manufacturer': 'Mobira Oy',
#   'Dimension in cm': '22 x 10 x 24',
#   'Weight in kg': '5,5',
#   'Materials': ['plastic', 'metal'],
#   'Colour': ['black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128133,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 13,
#   '_updated': None,
#   'year': 1985.0,
#   'ColourRGB': [[0, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/03/wsi-imageoptim-img_9261-2000x2896.jpg',
#   'Object group': 'devices',
#   'Color': [{'colorName': 'black', 'rgb': [0, 0, 0]}]},
#  {'_id': '634f1905b7693f159a62e2f4',
#   'title': 'Asa Futura',
#   'Object': 'TELEVISION',
#   'Special name': '*',
#   'id': '20260',
#   'author': 'Saura, Samuli',
#   'Production date': '1969',
#   'Collection': '*',
#   'Manufacturer': 'ASA Radio Oy Turku',
#   'Dimension in cm': '84 cm (height) x 57cm (width)',
#   'Weight in kg': '*',
#   'Materials': ['reinforcedplastic', 'castaluminium'],
#   'Colour': ['red'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128133,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 13,
#   '_updated': None,
#   'year': 1969.0,
#   'ColourRGB': [[255, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-asa-20260-320x415.jpg',
#   'Object group': 'devices',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]}]},
#  {'_id': '634f19056c70ef5cf152f235',
#   'title': 'C 1810 B',
#   'Object': 'JUICER',
#   'Special name': '*',
#   'id': '13154',
#   'author': 'Karjalainen, Heikki,  JÃ¤ntti, Mikko',
#   'Production date': '1965',
#   'Collection': '*',
#   'Manufacturer': 'Fiskars Oyj Abp',
#   'Dimension in cm': '20,5 x 23 x 28,5',
#   'Weight in kg': '*',
#   'Materials': ['plastic'],
#   'Colour': ['orange', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128133,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 13,
#   '_updated': None,
#   'year': 1965.0,
#   'ColourRGB': [[255, 165, 0], [255, 255, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/11/wsi-imageoptim-mehulinko-320x378.jpg',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'orange', 'rgb': [255, 165, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f19049d480d2bcc4ac7a4',
#   'title': 'Planetaariset Laaksot (Planetary Valleys)',
#   'Object': 'PIECE OF JEWELRY',
#   'Special name': 'necklace',
#   'id': '38267',
#   'author': 'WeckstrÃ¶m, BjÃ¶rn',
#   'Production date': '1969',
#   'Collection': '*',
#   'Manufacturer': 'Lapponia Jewelry Oy',
#   'Dimension in cm': '40,5 cm (length) x 25mm (width)',
#   'Weight in kg': '0,1',
#   'Materials': ['silver'],
#   'Colour': ['silver'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128132,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 12,
#   '_updated': None,
#   'year': 1969.0,
#   'ColourRGB': [[192, 192, 192]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/01/wsi-imageoptim-026918_planetaarisetlaaksot_p-2000x1333.jpg',
#   'Object group': 'jewelry',
#   'Color': [{'colorName': 'silver', 'rgb': [192, 192, 192]}]},
#  {'_id': '634f1904d8af1b50664089ce',
#   'title': 'Bo boo',
#   'Object': 'BAG',
#   'Special name': 'shoulder bag',
#   'id': '41581',
#   'author': 'Ratia, Ristomatti (model of the bag),  Wakisaka, Katsuji (print)',
#   'Production date': '1975',
#   'Collection': 'Marimekko',
#   'Manufacturer': 'Marimekko',
#   'Dimension in cm': '21,8 x 11,1 x 26,3',
#   'Weight in kg': '0,1',
#   'Materials': ['cotton', 'marquis'],
#   'Colour': ['yellow', ' green'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128132,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 12,
#   '_updated': None,
#   'year': 1975.0,
#   'ColourRGB': [[255, 255, 0], [0, 128, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/08/wsi-imageoptim-marimekko_laukku-1327x1600.jpg',
#   'Object group': 'clothes and accessories',
#   'Color': [{'colorName': 'yellow', 'rgb': [255, 255, 0]},
#    {'colorName': ' green', 'rgb': [0, 128, 0]}]},
#  {'_id': '634f1904e09bfd1d9a04b8f1',
#   'title': 'Nokia 9210 Communicator',
#   'Object': 'TELEPHONE',
#   'Special name': 'Communicator, smart phone',
#   'id': '41377',
#   'author': 'Johansson, Panu',
#   'Production date': '1998',
#   'Collection': '*',
#   'Manufacturer': 'Nokia Oyj',
#   'Dimension in cm': '5,6 cm (width) x 15,8cm (height) x 2,7cm (depth)',
#   'Weight in kg': '0,24',
#   'Materials': ['plastic', 'metal'],
#   'Colour': ['gray'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128132,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 12,
#   '_updated': None,
#   'year': 1998.0,
#   'ColourRGB': [[128, 128, 128]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-puhelin2-320x323.jpg',
#   'Object group': 'devices',
#   'Color': [{'colorName': 'gray', 'rgb': [128, 128, 128]}]},
#  {'_id': '634f190305fdc719f0345ae7',
#   'title': 'Monrepos, fabric: Keidas',
#   'Object': 'DRESS',
#   'Special name': 'long dress',
#   'id': '30074',
#   'author': 'Rimala, Annika',
#   'Production date': '1967',
#   'Collection': 'Marimekko',
#   'Manufacturer': 'Marimekko',
#   'Dimension in cm': '100 cm (length)',
#   'Weight in kg': '*',
#   'Materials': ['cotton'],
#   'Colour': ['green', ' orange', ' violet'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128131,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 11,
#   '_updated': None,
#   'year': 1967.0,
#   'ColourRGB': [[0, 128, 0], [255, 165, 0], [238, 130, 238]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2022/09/wsi-imageoptim-2812011103641rimala_monrepos_p-1327x1958.jpg',
#   'Object group': 'clothes and accessories',
#   'Color': [{'colorName': 'green', 'rgb': [0, 128, 0]},
#    {'colorName': ' orange', 'rgb': [255, 165, 0]},
#    {'colorName': ' violet', 'rgb': [238, 130, 238]}]},
#  {'_id': '634f1903d28967637e31c90a',
#   'title': 'Model 4, fabric: Sormus',
#   'Object': 'DRESS',
#   'Special name': 'dress',
#   'id': '27303',
#   'author': 'Nurmesniemi, Vuokko',
#   'Production date': '1964 - 1970',
#   'Collection': 'Vuokko',
#   'Manufacturer': 'Vuokko Oy',
#   'Dimension in cm': '99 cm (length)',
#   'Weight in kg': '*',
#   'Materials': ['wool'],
#   'Colour': ['yellow'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128131,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 11,
#   '_updated': None,
#   'year': 1967.0,
#   'ColourRGB': [[255, 255, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/03/wsi-imageoptim-22320118103827303-320x495.jpg',
#   'Object group': 'clothes and accessories',
#   'Color': [{'colorName': 'yellow', 'rgb': [255, 255, 0]}]},
#  {'_id': '634f1902b7693f159a62e2f2',
#   'title': 'Lappkojs',
#   'Object': 'PLAYTHING',
#   'Special name': 'doll',
#   'id': '38518',
#   'author': 'Franck, Kaj',
#   'Production date': '1945',
#   'Collection': '*',
#   'Manufacturer': 'Kotilieden Aitta',
#   'Dimension in cm': '14 x 9',
#   'Weight in kg': '0,2',
#   'Materials': ['wood'],
#   'Colour': ['wood', ' blue', ' red'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128130,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 10,
#   '_updated': None,
#   'year': 1945.0,
#   'ColourRGB': [[186, 140, 99], [0, 0, 255], [255, 0, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/09/wsi-imageoptim-38518-899x1299.jpg',
#   'Object group': 'ornamentation',
#   'Color': [{'colorName': 'wood', 'rgb': [186, 140, 99]},
#    {'colorName': ' blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' red', 'rgb': [255, 0, 0]}]},
#  {'_id': '634f19026c70ef5cf152f231',
#   'title': 'Fasaani 939.015.91 (Pheasant)',
#   'Object': 'GLASS SCULPTURE',
#   'Special name': 'bird',
#   'id': '13081',
#   'author': 'Toikka, Oiva',
#   'Production date': '1980',
#   'Collection': '*',
#   'Manufacturer': 'NuutajÃ¤rven lasi',
#   'Dimension in cm': '20 x 14',
#   'Weight in kg': '0,9',
#   'Materials': ['glass'],
#   'Colour': ['silver', ' red', ' green'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128130,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 10,
#   '_updated': None,
#   'year': 1980.0,
#   'ColourRGB': [[192, 192, 192], [255, 0, 0], [0, 128, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-13081-2000x2667.jpg',
#   'Object group': 'ornamentation',
#   'Color': [{'colorName': 'silver', 'rgb': [192, 192, 192]},
#    {'colorName': ' red', 'rgb': [255, 0, 0]},
#    {'colorName': ' green', 'rgb': [0, 128, 0]}]},
#  {'_id': '634f19025350725cb83093bc',
#   'title': 'Jokapoika, fabric: Piccolo',
#   'Object': 'BLOUSE',
#   'Special name': 'shirt',
#   'id': '41821',
#   'author': 'Nurmesniemi, Vuokko',
#   'Production date': 'Shirt 1956, fabric 1953',
#   'Collection': '*',
#   'Manufacturer': 'Marimekko Oyj',
#   'Dimension in cm': '80 cm (length)',
#   'Weight in kg': '*',
#   'Materials': ['cotton'],
#   'Colour': ['black', ' white'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128130,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 10,
#   '_updated': None,
#   'year': 1954.0,
#   'ColourRGB': [[0, 0, 0], [255, 255, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-es41602-2000x1806.jpg',
#   'Object group': 'clothes and accessories',
#   'Color': [{'colorName': 'black', 'rgb': [0, 0, 0]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]}]},
#  {'_id': '634f1901d8af1b50664089cc',
#   'title': 'Block',
#   'Object': 'LIGHT',
#   'Special name': 'desk lamp',
#   'id': '38467',
#   'author': 'Koskinen, Harri',
#   'Production date': '1996',
#   'Collection': '*',
#   'Manufacturer': 'Design House Stockholm',
#   'Dimension in cm': '1.0 x 1.6 x 0.9',
#   'Weight in kg': '3,7',
#   'Materials': ['glass'],
#   'Colour': ['colourless glass'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128129,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 9,
#   '_updated': None,
#   'year': 1996.0,
#   'ColourRGB': [],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-kk-1667x1075.jpg',
#   'Object group': 'devices',
#   'Color': []},
#  {'_id': '634f1901e09bfd1d9a04b8ef',
#   'title': 'Viimeinen ateria (The Last Supper)',
#   'Object': 'CERAMIC TILE',
#   'Special name': '*',
#   'id': '35971',
#   'author': 'Arabia / Bryk, Rut',
#   'Production date': '1950',
#   'Collection': '*',
#   'Manufacturer': 'Arabia / Bryk, Rut',
#   'Dimension in cm': '70,5 x 104 x 9',
#   'Weight in kg': '25',
#   'Materials': ['faience'],
#   'Colour': ['blue tones', ' several colours'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128129,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 9,
#   '_updated': None,
#   'year': 1950.0,
#   'ColourRGB': [[0, 0, 255]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2023/04/wsi-imageoptim-bryk_-ehtoollinen1950_arabia_kuvart_8-2-1667x1213.jpg',
#   'Object group': 'ornamentation',
#   'Color': [{'colorName': 'blue tones', 'rgb': [0, 0, 255]}]},
#  {'_id': '634f1901d4227a56290cb6c8',
#   'title': 'Pässi (Ram)',
#   'Object': 'DECORATIVE OBJECT',
#   'Special name': 'table decoration',
#   'id': '41768',
#   'author': 'Aarikka, Kaija',
#   'Production date': '1973',
#   'Collection': '*',
#   'Manufacturer': 'Aarikka Oy',
#   'Dimension in cm': '24 (height)',
#   'Weight in kg': '1,25',
#   'Materials': ['pine'],
#   'Colour': ['wood'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128129,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 9,
#   '_updated': None,
#   'year': 1973.0,
#   'ColourRGB': [[186, 140, 99]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-aarikka_passi-harry-kivilinna-1327x746.jpg',
#   'Object group': 'ornamentation',
#   'Color': [{'colorName': 'wood', 'rgb': [186, 140, 99]}]},
#  {'_id': '634f1900a45b33465c10ceaf',
#   'title': 'W19',
#   'Object': 'VASE',
#   'Special name': '*',
#   'id': 'B548',
#   'author': 'Finch, Alfred William',
#   'Production date': '1898-1902',
#   'Collection': '*',
#   'Manufacturer': 'Ab Iris Oy',
#   'Dimension in cm': '7,5 (base diameter) x 25 (height)',
#   'Weight in kg': '0,8',
#   'Materials': ['redclay'],
#   'Colour': ['brown', ' green', ' blue-green'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128128,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 8,
#   '_updated': None,
#   'year': 1900.0,
#   'ColourRGB': [[165, 42, 42], [0, 128, 0], [33, 165, 183]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/04/wsi-imageoptim-b548-2000x2665.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]},
#    {'colorName': ' green', 'rgb': [0, 128, 0]},
#    {'colorName': ' blue-green', 'rgb': [33, 165, 183]}]},
#  {'_id': '634f19009d480d2bcc4ac7a2',
#   'title': 'Salmenhaara vase',
#   'Object': 'VASE',
#   'Special name': '*',
#   'id': '17248',
#   'author': 'Salmenhaara, Kyllikki',
#   'Production date': '1957',
#   'Collection': '*',
#   'Manufacturer': 'Arabia / Salmenhaara, Kyllikki',
#   'Dimension in cm': '9 (base diameter) x 26,5',
#   'Weight in kg': '0,7',
#   'Materials': ['stoneware'],
#   'Colour': ['brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128128,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 8,
#   '_updated': None,
#   'year': 1957.0,
#   'ColourRGB': [[165, 42, 42]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-am6077-2000x2667.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f18ff5350725cb83093b9',
#   'title': 'Sauna stool',
#   'Object': 'SEAT',
#   'Special name': 'stool',
#   'id': '9321',
#   'author': 'Nurmesniemi, Antti',
#   'Production date': '1952',
#   'Collection': '*',
#   'Manufacturer': 'Liljamaan puusepÃ¤ntehdas',
#   'Dimension in cm': '43 x 43 (istuin, sÃ¤te, seat) x 43',
#   'Weight in kg': '4',
#   'Materials': ['birchplywood', 'teak', 'pinelaminate(seat)'],
#   'Colour': ['wood'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128127,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 7,
#   '_updated': None,
#   'year': 1952.0,
#   'ColourRGB': [[186, 140, 99]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/01/wsi-imageoptim-luku9_025492_nurmesniemi_saunajakkara_kuvart-compressor-2000x2074.jpg',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'wood', 'rgb': [186, 140, 99]}]},
#  {'_id': '634f18ff05fdc719f0345ae4',
#   'title': 'Savoy vase',
#   'Object': 'VASE',
#   'Special name': '*',
#   'id': '41793',
#   'author': 'Aalto, Alvar',
#   'Production date': '1936',
#   'Collection': '*',
#   'Manufacturer': 'Karhulan Lasi Oy',
#   'Dimension in cm': '16 x 20 x 17',
#   'Weight in kg': '1,55',
#   'Materials': ['glass'],
#   'Colour': ['rio brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128127,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 7,
#   '_updated': None,
#   'year': 1936.0,
#   'ColourRGB': [[181, 153, 142]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/02/wsi-imageoptim-img_9801-1327x1025.jpg',
#   'Object group': 'industrial design',
#   'Color': [{'colorName': 'rio brown', 'rgb': [181, 153, 142]}]},
#  {'_id': '634f18ffd28967637e31c907',
#   'title': 'Finch vase',
#   'Object': 'VASE',
#   'Special name': '*',
#   'id': '16101',
#   'author': 'Finch, Alfred William',
#   'Production date': '1898-1902',
#   'Collection': '*',
#   'Manufacturer': 'Ab Iris Oy',
#   'Dimension in cm': '12,5 (base diameter) x 19 (distance between two handles) x 21 (height)',
#   'Weight in kg': '1',
#   'Materials': ['redclay'],
#   'Colour': ['blue', ' white', ' brown'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128127,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 7,
#   '_updated': None,
#   'year': 1900.0,
#   'ColourRGB': [[0, 0, 255], [255, 255, 255], [165, 42, 42]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/04/wsi-imageoptim-16101-2000x2667.jpg',
#   'Object group': 'pots',
#   'Color': [{'colorName': 'blue', 'rgb': [0, 0, 255]},
#    {'colorName': ' white', 'rgb': [255, 255, 255]},
#    {'colorName': ' brown', 'rgb': [165, 42, 42]}]},
#  {'_id': '634f18fee09bfd1d9a04b8ec',
#   'title': 'Paimio / Armchair 41',
#   'Object': 'CHAIR',
#   'Special name': 'armchair',
#   'id': '9249',
#   'author': 'Aalto, Alvar',
#   'Production date': '1932',
#   'Collection': '*',
#   'Manufacturer': 'Artek, Huonekalutehdas Korhonen',
#   'Dimension in cm': '60 x 64 x 80',
#   'Weight in kg': '6',
#   'Materials': ['birch'],
#   'Colour': ['black', ' birch'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128126,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 6,
#   '_updated': None,
#   'year': 1932.0,
#   'ColourRGB': [[0, 0, 0], [223, 215, 200]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/01/wsi-imageoptim-06391_paimio_rt-2000x1372.jpg',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'black', 'rgb': [0, 0, 0]},
#    {'colorName': ' birch', 'rgb': [223, 215, 200]}]},
#  {'_id': '634f18fed4227a56290cb6c5',
#   'title': 'Pastille',
#   'Object': 'CHAIR',
#   'Special name': 'armchair',
#   'id': '44165',
#   'author': 'Aarnio, Eero',
#   'Production date': '1968',
#   'Collection': '*',
#   'Manufacturer': 'Asko Oy',
#   'Dimension in cm': '92 x 92 x 53',
#   'Weight in kg': '10',
#   'Materials': ['fiberglass'],
#   'Colour': ['yellow'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128126,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 6,
#   '_updated': None,
#   'year': 1968.0,
#   'ColourRGB': [[255, 255, 0]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-pastilli-rt-p-2000x1395.jpg',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'yellow', 'rgb': [255, 255, 0]}]},
#  {'_id': '634f18feb7693f159a62e2ef',
#   'title': 'High chair 616',
#   'Object': 'CHAIR',
#   'Special name': 'high chair',
#   'id': '9226',
#   'author': 'SchultÃ©n, Ben af',
#   'Production date': '1965',
#   'Collection': '*',
#   'Manufacturer': 'Artek Oy, Huonekalutehdas Korhonen Oy ja Norrcraft',
#   'Dimension in cm': '42,8 x 44 x 77',
#   'Weight in kg': '6',
#   'Materials': ['solidbirch', 'plywood'],
#   'Colour': ['red', ' birch'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128126,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 6,
#   '_updated': None,
#   'year': 1965.0,
#   'ColourRGB': [[255, 0, 0], [223, 215, 200]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/10/wsi-imageoptim-syottotuoli-320x410.jpg',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'red', 'rgb': [255, 0, 0]},
#    {'colorName': ' birch', 'rgb': [223, 215, 200]}]},
#  {'_id': '634f18fd9d480d2bcc4ac79f',
#   'title': 'Stool 60',
#   'Object': 'CHAIR',
#   'Special name': 'stool',
#   'id': '44163',
#   'author': 'Aalto, Alvar',
#   'Production date': '1933',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Artek',
#   'Dimension in cm': '38 x 38 x 44',
#   'Weight in kg': '2',
#   'Materials': ['birch'],
#   'Colour': ['birch'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128125,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 5,
#   '_updated': None,
#   'year': 1933.0,
#   'ColourRGB': [[223, 215, 200]],
#   'image': 'https://apicollection.designmuseum.fi/wp-content/uploads/2017/11/wsi-imageoptim-aalto_jakkara-1327x1998.jpg',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'birch', 'rgb': [223, 215, 200]}]},
#  {'_id': '634f18fdd8af1b50664089c9',
#   'title': 'Pirkka',
#   'Object': 'CHAIR',
#   'Special name': 'Small chair',
#   'id': '44164',
#   'author': 'Tapiovaara, Ilmari',
#   'Production date': '1955',
#   'Collection': 'KÃ¤yttÃ¶kokoelma',
#   'Manufacturer': 'Artek-Vitra',
#   'Dimension in cm': '76 x 41 x 38',
#   'Weight in kg': '2,2',
#   'Materials': ['pine'],
#   'Colour': ['pine', 'black'],
#   '_datasetid': '0daa0287-d7f4-4f03-a068-95f43afcc347',
#   '_timestamp': 1666128125,
#   '_timestamp_year': 2022,
#   '_timestamp_month': 10,
#   '_timestamp_day': 18,
#   '_timestamp_hour': 22,
#   '_timestamp_minute': 22,
#   '_timestamp_second': 5,
#   '_updated': None,
#   'year': 1955.0,
#   'ColourRGB': [[238, 213, 174], [0, 0, 0]],
#   'image': 'https://i.postimg.cc/76F876Dk/44164.png',
#   'Object group': 'furniture',
#   'Color': [{'colorName': 'pine', 'rgb': [238, 213, 174]},
#    {'colorName': 'black', 'rgb': [0, 0, 0]}]}]

# %%
itemIds = [item["_id"] for item in data ]

# %%
from colormath.color_objects import LabColor, sRGBColor
from colormath.color_conversions import convert_color
from colormath.color_diff import delta_e_cie1976, delta_e_cie1994, delta_e_cie2000, delta_e_cmc

import numpy as np
def patch_asscalar(a):
    return a.item()

setattr(np, "asscalar", patch_asscalar)

class EqualSim:
    def __init_(self):
        pass
    
    def compute(self,att1, att2):
        return 1.0 if att1==att2 else 0.0
    
class ColorSim:   
    def __init__(self, distanceFunction= delta_e_cie2000):
        self.__distanceFunction = distanceFunction
        
    def compute(self,att1, att2):
        # Att1 and Att2 must be objects that contain a rgb field (a lists with 3 elements (RGB) )
        if ("rgb" in att1) and (len(att1["rgb"])== 3) and ("rgb" in att2) and (len(att2["rgb"])== 3):
            rgb1 = sRGBColor(att1["rgb"][0], att1["rgb"][1], att1["rgb"][2], is_upscaled=True)
            lab1 = convert_color(rgb1,LabColor)

            rgb2 = sRGBColor(att2["rgb"][0], att2["rgb"][1], att2["rgb"][2], is_upscaled=True)
            lab2 = convert_color(rgb2,LabColor)
    
            # Apply distance function on Lab colors. delta functions return a value [0, 100]
            # so we normalize to [0.0, 1.0]
            deltaValue = self.__distanceFunction(lab1, lab2)/100
            # Clamp values greater than 1.0
            deltaValue = 1.0 if deltaValue>1.0 else deltaValue
            return 1.0-deltaValue
                
        else:
            return 0.0

        
class ListSim:
    def __init__(self, similarityFunction, aggFunction):
        self.__similarityFunction = similarityFunction
        self.__aggFunction = aggFunction

    def compute(self,list1, list2):
        if (type (list1) is not list) or len(list1) == 0:
            return 0.0
        if (type (list2) is not list) or len(list2) == 0:
            return 0.0
        # Choose the smaller list as list1
        if len(list1)>len(list2):
            tempList = list2
            list2 = list1
            list1 = tempList
        
        partialSims = []        
        for i in range(len(list1)):
            simValuesForItem = []
            for j in range(len(list2)):
                simValuesForItem.append(self.__similarityFunction.compute(list1[i], list2[j]))
            # Choose the best similarity value 
            partialSims.append( max(simValuesForItem) )  
        
        return self.__aggFunction.aggregate(partialSims)      
    
    
class AggregationFunction:
    def __init__(self, aggFunction=max):
        self.__aggFunction = aggFunction
        
    def aggregate(self,valueList):
        return self.__aggFunction(valueList)

# %%
def computeLocalSimilarityOnAttribute(itemA, itemB, attName, aLocalSimilarityFunction):
    if (attName in itemA) and (attName in itemB):
        return aLocalSimilarityFunction.compute(itemA[attName], itemB[attName])
    else:
        raise Exception("Attribute not found: "+attName) 


def weightedAverage(values, weights):
    return np.average(values, weights=weights)

def computeSimilarity(simDescription, data, idAtt, itemIds, localSimFunctions, globalAggFunction):
    size = len(itemIds)
    simData = []
    for i in range(size):
        for j in range (i+1, size):
            itemA = data[i]
            itemB = data[j]
            globalData = dict(id1 = itemA[idAtt], id2=itemB[idAtt])
            localData = {}
            localValues = []
            localWeights = []
            for localAtt in localSimFunctions:
                simValue = computeLocalSimilarityOnAttribute(itemA, itemB, localAtt["attName"], localAtt["localSimFunction"])
                localData[localAtt["attName"]] = simValue
                localValues.append(simValue)
                localWeights.append(localAtt["weight"])
            sim = globalAggFunction(localValues, localWeights)
            globalData["value"] = {"global": sim, "local": localData}
            simData.append(globalData)
    dataFile = dict(
        similarityDescription = simDescription,
        similarityData = simData
    )
    return dataFile

# %% [markdown]
# ## Color + author (0.5 - 0.5)

# %%
aSimilarityFunction = ColorSim()
anAggFunction = AggregationFunction()
theColorSimFunction = ListSim(aSimilarityFunction, anAggFunction)

localSimFunctions = [ dict(attName="Color", localSimFunction=theColorSimFunction, weight=0.5), 
                      dict(attName="author", localSimFunction=EqualSim(), weight=0.5)]

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Color = dict(
            simFunction = "max(delta_e2000)",
            weight = 0.5,
            description = f'Maximum similarity value between two sets of colors. Similarity between a pair of colors is computed using [Delta E 2000 color difference function](http://www.colorwiki.com/wiki/Delta_E:_The_Color_Difference#dE2000)'
        ),
        author = dict(
            simFunction = "equals",
            weight = 0.5,
            description = "String equality"
        )
    )
)

dataFile = computeSimilarity(simDescription, data, "_id", itemIds, localSimFunctions, weightedAverage)
with open("./DMH/Author50Color50.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# ## Color + author (0.8 - 0.2)

# %%
simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Color = dict(
            simFunction = "max(delta_e2000)",
            weight = 0.8,
            description = f'Maximum similarity value between two sets of colors. Similarity between a pair of colors is computed using [Delta E 2000 color difference function](http://www.colorwiki.com/wiki/Delta_E:_The_Color_Difference#dE2000)'
        ),
        author = dict(
            simFunction = "equals",
            weight = 0.2,
            description = "String equality"
        )
    )
)

localSimFunctions = [ dict(attName="Color", localSimFunction=theColorSimFunction, weight=0.8), 
                      dict(attName="author", localSimFunction=EqualSim(), weight=0.2)]

dataFile = computeSimilarity(simDescription, data, "_id", itemIds, localSimFunctions, weightedAverage)
with open("./DMH/Author80Color20.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# ## max(Color)
#
# The similarity is the maximum color similarity between colors in artworks

# %%
localSimFunctions = [ dict(attName="Color", localSimFunction=theColorSimFunction, weight=1.0)]
simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Color = dict(
            simFunction = "max(delta_e2000)",
            weight = 1.0,
            description = f'Maximum similarity value between two sets of colors. Similarity between a pair of colors is computed using [Delta E 2000 color difference function](http://www.colorwiki.com/wiki/Delta_E:_The_Color_Difference#dE2000)'
        )
    )
)
dataFile = computeSimilarity(simDescription, data, "_id", itemIds, localSimFunctions, weightedAverage)
with open("./DMH/MaxColor.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# ## avg(Color)
#
# The similarity is the average color similarity between colors in artworks

# %%
aSimilarityFunction = ColorSim()
anAggFunction = AggregationFunction(np.average)
theColorSimFunction = ListSim(aSimilarityFunction, anAggFunction)

localSimFunctions = [ dict(attName="Color", localSimFunction=theColorSimFunction, weight=1.0)]
simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Color = dict(
            simFunction = "avg(delta_e2000)",
            weight = 1.0,
            description = f'Average value of the maximum similarity values between pairs of colors. Pairs are created using the shortest color list and the colors in the other list.\nSimilarity between a pair of colors is computed using [Delta E 2000 color difference function](http://www.colorwiki.com/wiki/Delta_E:_The_Color_Difference#dE2000)'
        )
    )
)
dataFile = computeSimilarity(simDescription, data, "_id", itemIds, localSimFunctions, weightedAverage)
with open("./DMH/AvgColor.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# ## range(decades)
#
# The similarity is computed using the year, according to the similarity between the decades that the year belong to

# %%
class DecadeSimilarity:
    def __init__(self, minYear, maxYear):
        self.minDecade = self.convertYearToDecade(minYear)
        self.maxDecade = self.convertYearToDecade(maxYear)
        self.decadeRange = self.maxDecade - self.minDecade
    
    def compute(self,year1, year2):
        if (year1 is not None) and (year2 is not None):
            decade1 = self.convertYearToDecade(year1)
            decade2 = self.convertYearToDecade(year2)

            normalizeDecade1 = (decade1 - self.minDecade) / self.decadeRange
            normalizeDecade2 = (decade2 - self.minDecade) / self.decadeRange
            return 1-abs(normalizeDecade2 - normalizeDecade1)
        else:
            return 0.0
    
    def convertYearToDecade(self,year):
        return int((year-1)/10) * 10

# %%
years = [item["year"] for item in data if item["year"] is not None]

    
decadeSimilarityFunction = DecadeSimilarity(min(years), max(years))
localSimFunctions = [ dict(attName="year", localSimFunction=decadeSimilarityFunction, weight=1.0)]
simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        year = dict(
            simFunction = "Range(Decades)",
            weight = 1.0,
            description = "Similarity computed using the Decade value in the range of decades for the dataset"
        )
    )
)

dataFile = computeSimilarity(simDescription, data, "_id", itemIds, localSimFunctions, weightedAverage)
with open("./DMH/Decades.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# # Blood Alcohol Domain
#
# Available at: <https://github.com/gateslm/Blood-Alcohol-Domain>
#
# ```math
# @misc{BAC23,
#   title = {Blood Alcohol Content Domain},
#   howpublished={\url{https://github.com/gateslm/Blood-Alcohol-Domain}},
#   year = {2023},
#   url={https://github.com/gateslm/Blood-Alcohol-Domain},
#   author = {Doyle, D{\'o}nal and Cunningham, P{\'a}draig, and Coyle, Lorcan}
# }
# ```
#
# Used in: <https://link-springer-com.bucm.idm.oclc.org/chapter/10.1007/978-3-031-40177-0_10>

# %%
import pandas as pd
df = pd.read_csv('./blood-alcohol/blood-alcohol-domain.csv', index_col='casename')
newColumns = [name.replace("features__", "") for name in df.columns.values]
df.columns = newColumns
df
# Out:
#           Gender  FrameSize  AmountConsumed   Meal  Duration solution
# casename
# n1          male          1               1  snack        60      0.2
# n2        female          2               3   none       120      0.8
# n3        female          4               4   full        90      0.8
# n4          male          4               6   none       120    1.0++
# n5          male          4               3   none        60      0.5
# ...          ...        ...             ...    ...       ...      ...
# n81         male          4               5   none       120      0.8
# n82         male          5               5   none       120      0.7
# n83         male          6               5   none       120      0.6
# n84         male          7               5  snack       120      0.5
# n85         male          7               5   none       120      0.5
#
# [85 rows x 6 columns]

# %%
df.reset_index(inplace=True)
content = json.loads(df.to_json(orient='records'))

# %%
dataFile = dict(
    description = "Blood Alcohol Domain with additional files about processing and background information.", 
    attributes = dict(
        casename= "string",
        Gender= "string",
        FrameSize= "number",
        AmountConsumed= "number",
        Meal= "string",
        Duration= "number",
        solution= "string"
    ),
    id= "casename",
    data= content
)

# %%
with open("./blood-alcohol/blood-alcohol-domain.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %%
class RangeSimilarity:
    def __init__(self, minValue, maxValue):
        self.minValue = minValue
        self.maxValue = maxValue
        self.range = abs(self.maxValue - self.minValue)
    
    def compute(self,v1, v2):
        if (v1 is not None)  and (v1>=self.minValue) and (v1<=self.maxValue) and (v2 is not None) and (v2>=self.minValue) and (v2<=self.maxValue):
            normalizeV1 = (v1 - self.minValue) / self.range
            normalizeV2 = (v2 - self.minValue) / self.range
            return 1-abs(normalizeV2 - normalizeV1)
        else:
            return 0.0

class NominalRangeSimilarity(RangeSimilarity):
    def __init__(self, listNominalValues):
        self.values = listNominalValues
        super().__init__(0, len(listNominalValues)-1)
    def compute(self,v1, v2):
        if (v1 in self.values) and (v2 in self.values):
            indexV1 = self.values.index(v1)
            indexV2 = self.values.index(v2)
            return super().compute(indexV1, indexV2)
        else:
            return 0.0

# %%
itemIds = [item["casename"] for item in content ]
localSimFunctions = [ dict(attName="Gender", localSimFunction=EqualSim(), weight=0.25), 
                      dict(attName="AmountConsumed", localSimFunction=RangeSimilarity(1,14), weight=0.25),
                      dict(attName="Meal", localSimFunction=NominalRangeSimilarity(['none', 'snack', 'full']), weight=0.25),
                      dict(attName="Duration", localSimFunction=RangeSimilarity(30,240), weight=0.25)]

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Gender = dict(
            simFunction = "equals",
            weight = 0.25
        ),
        AmountConsumed = dict(
            simFunction = "RangeSimilarity",
            weight = 0.25
        ),
        Meal = dict(
            simFunction = "NominalRangeSimilarity",
            weight = 0.25,
            description = "Similarity in an ordered cualitative range (none, snack, full)"
        ),
        Duration = dict(
            simFunction = "RangeSimilarity",
            weight = 0.25
        ),
    )
)

dataFile = computeSimilarity(simDescription, content, "casename", itemIds, localSimFunctions, weightedAverage)
with open("./blood-alcohol/GenderAmountMealDuration.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %%
itemIds = [item["casename"] for item in content ]
localSimFunctions = [ dict(attName="Gender", localSimFunction=EqualSim(), weight=0.25), 
                      dict(attName="AmountConsumed", localSimFunction=RangeSimilarity(1,14), weight=0.25),
                      dict(attName="Meal", localSimFunction=NominalRangeSimilarity(['none', 'snack', 'full']), weight=0.25),
                      dict(attName="FrameSize", localSimFunction=RangeSimilarity(1,8), weight=0.25)]

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        Gender = dict(
            simFunction = "equals",
            weight = 0.25
        ),
        AmountConsumed = dict(
            simFunction = "RangeSimilarity",
            weight = 0.25
        ),
        Meal = dict(
            simFunction = "NominalRangeSimilarity",
            weight = 0.25,
            description = "Similarity in an ordered cualitative range (none, snack, full)"
        ),
        FrameSize = dict(
            simFunction = "RangeSimilarity",
            weight = 0.25
        ),
    )
)

dataFile = computeSimilarity(simDescription, content, "casename", itemIds, localSimFunctions, weightedAverage)
with open("./blood-alcohol/GenderAmountMealFrameSize.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %%
itemIds = [item["casename"] for item in content ]
localSimFunctions = [ dict(attName="AmountConsumed", localSimFunction=RangeSimilarity(1,14), weight=0.33),
                      dict(attName="Meal", localSimFunction=NominalRangeSimilarity(['none', 'snack', 'full']), weight=0.33),
                      dict(attName="FrameSize", localSimFunction=RangeSimilarity(1,8), weight=0.33)]

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        AmountConsumed = dict(
            simFunction = "RangeSimilarity",
            weight = 0.33
        ),
        Meal = dict(
            simFunction = "NominalRangeSimilarity",
            weight = 0.33,
            description = "Similarity in an ordered cualitative range (none, snack, full)"
        ),
        FrameSize = dict(
            simFunction = "RangeSimilarity",
            weight = 0.33
        ),
    )
)

dataFile = computeSimilarity(simDescription, content, "casename", itemIds, localSimFunctions, weightedAverage)
with open("./blood-alcohol/AmountMealFrameSize.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %% [markdown]
# # Breast Cancer Wisconsin Data
#
# <https://archive.ics.uci.edu/dataset/15/breast+cancer+wisconsin+original>

# %%
columnNames = ["SampleNumber",
"ClumpThickness",
"UniformityCellSize",
"UniformityCellShape",
"MarginalAdhesion",
"SingleEpithelialCellSize",
"BareNuclei",
"BlandChromatin",
"NormalNucleoli",
"Mitoses",
"Class"]
df = pd.read_csv("./BCWD/breast-cancer-wisconsin.csv", header=None, names=columnNames)
df.drop(labels=['SampleNumber'], axis=1, inplace=True)
df.reset_index(inplace=True)
df.columns = columnNames
df["SampleNumber"] = df["SampleNumber"].apply(lambda v: "c"+str(v))
df
# Out:
#     SampleNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0             c0               5                   1                    1
# 1             c1               5                   4                    4
# 2             c2               3                   1                    1
# 3             c3               6                   8                    8
# 4             c4               4                   1                    1
# ..           ...             ...                 ...                  ...
# 694         c694               3                   1                    1
# 695         c695               2                   1                    1
# 696         c696               5                  10                   10
# 697         c697               4                   8                    6
# 698         c698               4                   8                    8
#
#      MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                   1                         2          1               3
# 1                   5                         7         10               3
# 2                   1                         2          2               3
# 3                   1                         3          4               3
# 4                   3                         2          1               3
# ..                ...                       ...        ...             ...
# 694                 1                         3          2               1
# 695                 1                         2          1               1
# 696                 3                         7          3               8
# 697                 4                         3          4              10
# 698                 5                         4          5              10
#
#      NormalNucleoli  Mitoses  Class
# 0                 1        1      2
# 1                 2        1      2
# 2                 1        1      2
# 3                 7        1      2
# 4                 1        1      2
# ..              ...      ...    ...
# 694               1        1      2
# 695               1        1      2
# 696              10        2      4
# 697               6        1      4
# 698               4        1      4
#
# [699 rows x 11 columns]

# %%
df['Class'] = df['Class'].apply(lambda value:'benign' if value==2 else 'malignant')
df["BareNuclei"] = df["BareNuclei"].apply(lambda value: 0 if value== '?' else int(value))

# %%
content = json.loads(df.to_json(orient='records'))
content
# Out:
# [{'SampleNumber': 'c0',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c1',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 5,
#   'SingleEpithelialCellSize': 7,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c2',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c3',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 4,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 7,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c4',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c5',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 7,
#   'BareNuclei': 10,
#   'BlandChromatin': 9,
#   'NormalNucleoli': 7,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c6',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c7',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c8',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 5,
#   'Class': 'benign'},
#  {'SampleNumber': 'c9',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c10',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c11',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c12',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c13',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c14',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 7,
#   'BareNuclei': 9,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 5,
#   'Mitoses': 4,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c15',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 1,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c16',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c17',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c18',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 10,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 1,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c19',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c20',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 4,
#   'Mitoses': 4,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c21',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 7,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c22',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c23',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 0,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c24',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c25',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 7,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 6,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c26',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c27',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c28',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c29',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c30',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c31',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c32',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 5,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 4,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c33',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c34',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c35',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c36',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 1,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 9,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c37',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c38',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 9,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 6,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c39',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 7,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 5,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c40',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 9,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 0,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 8,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c41',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 3,
#   'BlandChromatin': 6,
#   'NormalNucleoli': 5,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c42',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 3,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c43',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c44',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 1,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c45',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 2,
#   'Class': 'benign'},
#  {'SampleNumber': 'c46',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 9,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 8,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c47',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c48',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c49',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 8,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 8,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c50',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 5,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c51',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 4,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c52',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 5,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 10,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c53',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 8,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 3,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c54',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 8,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c55',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 5,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 6,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c56',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 6,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 9,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c57',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 1,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 4,
#   'Mitoses': 4,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c58',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c59',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c60',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 5,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 3,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c61',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c62',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 8,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c63',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 9,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c64',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c65',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 2,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 3,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c66',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c67',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 9,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c68',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 9,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 9,
#   'Mitoses': 8,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c69',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c70',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c71',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 2,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 8,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c72',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c73',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 10,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 8,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c74',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 4,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c75',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c76',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c77',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c78',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c79',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c80',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c81',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c82',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c83',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c84',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 9,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 10,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c85',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 4,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 10,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c86',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 8,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c87',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 6,
#   'NormalNucleoli': 8,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c88',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c89',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c90',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c91',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c92',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c93',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c94',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c95',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c96',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c97',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c98',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 9,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 6,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 9,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c99',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 9,
#   'Mitoses': 4,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c100',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 5,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 10,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c101',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 5,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 5,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c102',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c103',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 3,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c104',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 1,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 8,
#   'Mitoses': 8,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c105',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 3,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c106',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 10,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c107',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 7,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c108',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c109',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 9,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 8,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c110',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 3,
#   'Mitoses': 2,
#   'Class': 'benign'},
#  {'SampleNumber': 'c111',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 9,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c112',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 3,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c113',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 8,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c114',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c115',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 5,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c116',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c117',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 5,
#   'Mitoses': 8,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c118',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 3,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c119',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c120',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c121',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c122',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 3,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c123',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c124',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 7,
#   'SingleEpithelialCellSize': 9,
#   'BareNuclei': 7,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c125',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c126',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 7,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 5,
#   'Mitoses': 5,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c127',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c128',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 6,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c129',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c130',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c131',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c132',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 6,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c133',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c134',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c135',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c136',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c137',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c138',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c139',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 0,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c140',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c141',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c142',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 5,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 3,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c143',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 5,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c144',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c145',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 0,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c146',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 8,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c147',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 2,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c148',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 1,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 8,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c149',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 8,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c150',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c151',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 4,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c152',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 5,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c153',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 3,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c154',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c155',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 5,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 6,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c156',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c157',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c158',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 0,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c159',
#   'ClumpThickness': 9,
#   'UniformityCellSize': 9,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 10,
#   'Mitoses': 6,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c160',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 7,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c161',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c162',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c163',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 3,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 7,
#   'Class': 'benign'},
#  {'SampleNumber': 'c164',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 0,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c165',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 2,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c166',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 10,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c167',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c168',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c169',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 1,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c170',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c171',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c172',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c173',
#   'ClumpThickness': 6,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 10,
#   'BlandChromatin': 10,
#   'NormalNucleoli': 10,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c174',
#   'ClumpThickness': 8,
#   'UniformityCellSize': 6,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 10,
#   'BlandChromatin': 6,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c175',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 7,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 7,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c176',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c177',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 1,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 10,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c178',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c179',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 10,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c180',
#   'ClumpThickness': 1,
# ...
#   'Class': 'benign'},
#  {'SampleNumber': 'c639',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c640',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c641',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c642',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c643',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c644',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c645',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c646',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c647',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c648',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 10,
#   'BareNuclei': 2,
#   'BlandChromatin': 10,
#   'NormalNucleoli': 10,
#   'Mitoses': 10,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c649',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c650',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 4,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c651',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c652',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c653',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c654',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c655',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c656',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c657',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 4,
#   'UniformityCellShape': 5,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 8,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 6,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c658',
#   'ClumpThickness': 7,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 7,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 10,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 2,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c659',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c660',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c661',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c662',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c663',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 3,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c664',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c665',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c666',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 2,
#   'Class': 'benign'},
#  {'SampleNumber': 'c667',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c668',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 7,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 6,
#   'BareNuclei': 1,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 10,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c669',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 5,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 10,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c670',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 7,
#   'MarginalAdhesion': 8,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 8,
#   'BlandChromatin': 7,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c671',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 2,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 2,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c672',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c673',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 3,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c674',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c675',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 4,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c676',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 2,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c677',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c678',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c679',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c680',
#   'ClumpThickness': 10,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 5,
#   'BareNuclei': 10,
#   'BlandChromatin': 10,
#   'NormalNucleoli': 10,
#   'Mitoses': 7,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c681',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 10,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 10,
#   'BlandChromatin': 5,
#   'NormalNucleoli': 6,
#   'Mitoses': 3,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c682',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 3,
#   'NormalNucleoli': 2,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c683',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c684',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c685',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c686',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c687',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 3,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c688',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c689',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 8,
#   'Class': 'benign'},
#  {'SampleNumber': 'c690',
#   'ClumpThickness': 1,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c691',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 5,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 5,
#   'BlandChromatin': 4,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c692',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c693',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 2,
#   'NormalNucleoli': 1,
#   'Mitoses': 2,
#   'Class': 'benign'},
#  {'SampleNumber': 'c694',
#   'ClumpThickness': 3,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 2,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c695',
#   'ClumpThickness': 2,
#   'UniformityCellSize': 1,
#   'UniformityCellShape': 1,
#   'MarginalAdhesion': 1,
#   'SingleEpithelialCellSize': 2,
#   'BareNuclei': 1,
#   'BlandChromatin': 1,
#   'NormalNucleoli': 1,
#   'Mitoses': 1,
#   'Class': 'benign'},
#  {'SampleNumber': 'c696',
#   'ClumpThickness': 5,
#   'UniformityCellSize': 10,
#   'UniformityCellShape': 10,
#   'MarginalAdhesion': 3,
#   'SingleEpithelialCellSize': 7,
#   'BareNuclei': 3,
#   'BlandChromatin': 8,
#   'NormalNucleoli': 10,
#   'Mitoses': 2,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c697',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 6,
#   'MarginalAdhesion': 4,
#   'SingleEpithelialCellSize': 3,
#   'BareNuclei': 4,
#   'BlandChromatin': 10,
#   'NormalNucleoli': 6,
#   'Mitoses': 1,
#   'Class': 'malignant'},
#  {'SampleNumber': 'c698',
#   'ClumpThickness': 4,
#   'UniformityCellSize': 8,
#   'UniformityCellShape': 8,
#   'MarginalAdhesion': 5,
#   'SingleEpithelialCellSize': 4,
#   'BareNuclei': 5,
#   'BlandChromatin': 10,
#   'NormalNucleoli': 4,
#   'Mitoses': 1,
#   'Class': 'malignant'}]

# %%
dataFile = dict(
    description = "[Breast Cancer Wisconsin Data](https://archive.ics.uci.edu/dataset/15/breast+cancer+wisconsin+original)", 
    attributes = {
        "SampleNumber": "string",
        "ClumpThickness": "number",
        "UniformityCellSize": "number",
        "UniformityCellShape": "number",
        "MarginalAdhesion": "number",
        "SingleEpithelialCellSize": "number",
        "BareNuclei": "number",
        "BlandChromatin": "number",
        "NormalNucleoli": "number",
        "Mitoses": "number",
        "Class": "string"
    },
    id= "SampleNumber",
    data= content
)

# %%
with open("./BCWD/bcwd.json", "w") as fp:
    json.dump(dataFile, fp)

# %%
itemIds = [item["SampleNumber"] for item in content ]
atts = columnNames[1:-1]
localSimFunctions = [dict(attName=name, localSimFunction=RangeSimilarity(1,14), weight=1/len(atts)) for name in atts]

localSim = {}
value = dict(simFunction = "RangeSimilarity", weight=1/len(atts))
for att in atts:
    localSim[att]=value
    

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = localSim
)

dataFile = computeSimilarity(simDescription, content, "SampleNumber", itemIds, localSimFunctions, weightedAverage)
with open("./BCWD/AllAttributes.json", "w") as fp:
    json.dump(dataFile, fp)

# %% [markdown]
# # Travel dataset
#
# A toy dataset about travels.

# %%
df = pd.read_csv("./travel/travel.csv")
df
# Out:
#            caseId HolidayType  Price  NumberOfPersons  Region Transportation  \
# 0        Journey1     Bathing   2498                2   Egypt          Plane
# 1        Journey2     Bathing   3066                3   Egypt          Plane
# 2        Journey3      Active   2778                2   Egypt          Plane
# 3        Journey4     Bathing   3195                3   Egypt          Plane
# 4        Journey5     Bathing   3158                2   Egypt          Plane
# ...           ...         ...    ...              ...     ...            ...
# 1019  Journey1020      Skiing   1094                5  France            Car
# 1020  Journey1021  Recreation   1728                6  France            Car
# 1021  Journey1022      Active    589                4  France            Car
# 1022  Journey1023      Skiing    589                4  France            Car
# 1023  Journey1024  Recreation   1574                4  France            Car
#
#       Duration     Season Accomodation                          Hotel
# 0           14      April     TwoStars       Hotel White House, Egypt
# 1           21        May     TwoStars       Hotel White House, Egypt
# 2           14       June     TwoStars            Hotel Geisum, Egypt
# 3            7       July   ThreeStars      Hotel Al Mashrabia, Egypt
# 4           14  September   ThreeStars      Hotel Al Mashrabia, Egypt
# ...        ...        ...          ...                            ...
# 1019         7   February  HolidayFlat    H.Flat Cheval Blanc, France
# 1020        14    January  HolidayFlat    H.Flat Cheval Blanc, France
# 1021         7   December  HolidayFlat  H.Flat Les Olympiades, France
# 1022         7    January  HolidayFlat  H.Flat Les Olympiades, France
# 1023         7   February  HolidayFlat  H.Flat Les Olympiades, France
#
# [1024 rows x 10 columns]

# %%
df['Duration'].unique()
# Out:
# array([14, 21,  7,  3,  4,  8, 10,  6,  9])

# %%
content = json.loads(df.to_json(orient='records'))
content
# Out:
# [{'caseId': 'Journey1',
#   'HolidayType': 'Bathing',
#   'Price': 2498,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'April',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel White House, Egypt'},
#  {'caseId': 'Journey2',
#   'HolidayType': 'Bathing',
#   'Price': 3066,
#   'NumberOfPersons': 3,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 21,
#   'Season': 'May',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel White House, Egypt'},
#  {'caseId': 'Journey3',
#   'HolidayType': 'Active',
#   'Price': 2778,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Geisum, Egypt'},
#  {'caseId': 'Journey4',
#   'HolidayType': 'Bathing',
#   'Price': 3195,
#   'NumberOfPersons': 3,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Al Mashrabia, Egypt'},
#  {'caseId': 'Journey5',
#   'HolidayType': 'Bathing',
#   'Price': 3158,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Al Mashrabia, Egypt'},
#  {'caseId': 'Journey6',
#   'HolidayType': 'Active',
#   'Price': 3318,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'October',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Al Mashrabia, Egypt'},
#  {'caseId': 'Journey7',
#   'HolidayType': 'Bathing',
#   'Price': 2458,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Winter Palace, Egypt'},
#  {'caseId': 'Journey8',
#   'HolidayType': 'Active',
#   'Price': 2649,
#   'NumberOfPersons': 3,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Winter Palace, Egypt'},
#  {'caseId': 'Journey9',
#   'HolidayType': 'Education',
#   'Price': 4638,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 21,
#   'Season': 'April',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Anlage Arabia Beach, Egypt'},
#  {'caseId': 'Journey10',
#   'HolidayType': 'Education',
#   'Price': 3738,
#   'NumberOfPersons': 2,
#   'Region': 'Egypt',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'October',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Anlage Arabia Beach, Egypt'},
#  {'caseId': 'Journey11',
#   'HolidayType': 'City',
#   'Price': 1978,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'April',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Victoria, Cairo'},
#  {'caseId': 'Journey12',
#   'HolidayType': 'City',
#   'Price': 1898,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Victoria, Cairo'},
#  {'caseId': 'Journey13',
#   'HolidayType': 'City',
#   'Price': 2158,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Victoria, Cairo'},
#  {'caseId': 'Journey14',
#   'HolidayType': 'City',
#   'Price': 1898,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Victoria, Cairo'},
#  {'caseId': 'Journey15',
#   'HolidayType': 'City',
#   'Price': 1154,
#   'NumberOfPersons': 1,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'October',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel New Marwa Palace, Cairo'},
#  {'caseId': 'Journey16',
#   'HolidayType': 'City',
#   'Price': 2308,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'April',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel New Marwa Palace, Cairo'},
#  {'caseId': 'Journey17',
#   'HolidayType': 'City',
#   'Price': 2658,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel New Marwa Palace, Cairo'},
#  {'caseId': 'Journey18',
#   'HolidayType': 'City',
#   'Price': 1269,
#   'NumberOfPersons': 1,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel New Marwa Palace, Cairo'},
#  {'caseId': 'Journey19',
#   'HolidayType': 'City',
#   'Price': 2608,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hotel Moevenpick, Cairo'},
#  {'caseId': 'Journey20',
#   'HolidayType': 'City',
#   'Price': 2468,
#   'NumberOfPersons': 2,
#   'Region': 'Cairo',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hotel Moevenpick, Cairo'},
#  {'caseId': 'Journey21',
#   'HolidayType': 'Recreation',
#   'Price': 1568,
#   'NumberOfPersons': 2,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Ostend, Belgium'},
#  {'caseId': 'Journey22',
#   'HolidayType': 'Active',
#   'Price': 798,
#   'NumberOfPersons': 3,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Ostend, Belgium'},
#  {'caseId': 'Journey23',
#   'HolidayType': 'Recreation',
#   'Price': 978,
#   'NumberOfPersons': 3,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Acces Hotel Mercure, Belgium'},
#  {'caseId': 'Journey24',
#   'HolidayType': 'Recreation',
#   'Price': 978,
#   'NumberOfPersons': 2,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Acces Hotel Mercure, Belgium'},
#  {'caseId': 'Journey25',
#   'HolidayType': 'Active',
#   'Price': 1448,
#   'NumberOfPersons': 3,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Belgium'},
#  {'caseId': 'Journey26',
#   'HolidayType': 'Recreation',
#   'Price': 1638,
#   'NumberOfPersons': 4,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Belgium'},
#  {'caseId': 'Journey27',
#   'HolidayType': 'Recreation',
#   'Price': 1079,
#   'NumberOfPersons': 4,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Belgium'},
#  {'caseId': 'Journey28',
#   'HolidayType': 'Bathing',
#   'Price': 499,
#   'NumberOfPersons': 4,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 3,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Belgium'},
#  {'caseId': 'Journey29',
#   'HolidayType': 'Bathing',
#   'Price': 399,
#   'NumberOfPersons': 6,
#   'Region': 'Belgium',
#   'Transportation': 'Car',
#   'Duration': 3,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Belgium'},
#  {'caseId': 'Journey30',
#   'HolidayType': 'Recreation',
#   'Price': 1928,
#   'NumberOfPersons': 2,
#   'Region': 'Belgium',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Acces Hotel Mercure, Belgium'},
#  {'caseId': 'Journey31',
#   'HolidayType': 'Bathing',
#   'Price': 1598,
#   'NumberOfPersons': 2,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Amfibia, Sunny Beach'},
#  {'caseId': 'Journey32',
#   'HolidayType': 'Bathing',
#   'Price': 2043,
#   'NumberOfPersons': 3,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Hemus, Sunny Beach'},
#  {'caseId': 'Journey33',
#   'HolidayType': 'Bathing',
#   'Price': 1658,
#   'NumberOfPersons': 4,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Raliza, Albena'},
#  {'caseId': 'Journey34',
#   'HolidayType': 'Bathing',
#   'Price': 1558,
#   'NumberOfPersons': 2,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Phoenix, Sunny Beach'},
#  {'caseId': 'Journey35',
#   'HolidayType': 'Active',
#   'Price': 1718,
#   'NumberOfPersons': 2,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Nessebar, Sunny Beach'},
#  {'caseId': 'Journey36',
#   'HolidayType': 'Bathing',
#   'Price': 1383,
#   'NumberOfPersons': 3,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Gergana, Albena'},
#  {'caseId': 'Journey37',
#   'HolidayType': 'Bathing',
#   'Price': 3628,
#   'NumberOfPersons': 4,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 21,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Orlav, Albena'},
#  {'caseId': 'Journey38',
#   'HolidayType': 'Active',
#   'Price': 2739,
#   'NumberOfPersons': 3,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Burgas, Sunny Beach'},
#  {'caseId': 'Journey39',
#   'HolidayType': 'Bathing',
#   'Price': 2399,
#   'NumberOfPersons': 2,
#   'Region': 'Bulgaria',
#   'Transportation': 'Plane',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Grandhotel Varna, Albena'},
#  {'caseId': 'Journey40',
#   'HolidayType': 'Bathing',
#   'Price': 2273,
#   'NumberOfPersons': 3,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey41',
#   'HolidayType': 'Bathing',
#   'Price': 1729,
#   'NumberOfPersons': 5,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey42',
#   'HolidayType': 'Bathing',
#   'Price': 1389,
#   'NumberOfPersons': 4,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey43',
#   'HolidayType': 'Recreation',
#   'Price': 968,
#   'NumberOfPersons': 6,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'April',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey44',
#   'HolidayType': 'Recreation',
#   'Price': 489,
#   'NumberOfPersons': 6,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey45',
#   'HolidayType': 'Recreation',
#   'Price': 489,
#   'NumberOfPersons': 6,
#   'Region': 'Bornholm',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Bornholm'},
#  {'caseId': 'Journey46',
#   'HolidayType': 'Bathing',
#   'Price': 2838,
#   'NumberOfPersons': 4,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Fano'},
#  {'caseId': 'Journey47',
#   'HolidayType': 'Bathing',
#   'Price': 1399,
#   'NumberOfPersons': 6,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Fano'},
#  {'caseId': 'Journey48',
#   'HolidayType': 'Recreation',
#   'Price': 958,
#   'NumberOfPersons': 6,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Fano'},
#  {'caseId': 'Journey49',
#   'HolidayType': 'Recreation',
#   'Price': 579,
#   'NumberOfPersons': 3,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Romo'},
#  {'caseId': 'Journey50',
#   'HolidayType': 'Recreation',
#   'Price': 789,
#   'NumberOfPersons': 5,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Romo'},
#  {'caseId': 'Journey51',
#   'HolidayType': 'Recreation',
#   'Price': 2839,
#   'NumberOfPersons': 10,
#   'Region': 'Fano',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Romo'},
#  {'caseId': 'Journey52',
#   'HolidayType': 'Bathing',
#   'Price': 629,
#   'NumberOfPersons': 6,
#   'Region': 'Lolland',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Lolland'},
#  {'caseId': 'Journey53',
#   'HolidayType': 'Bathing',
#   'Price': 1598,
#   'NumberOfPersons': 4,
#   'Region': 'Lolland',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Lolland'},
#  {'caseId': 'Journey54',
#   'HolidayType': 'Recreation',
#   'Price': 429,
#   'NumberOfPersons': 8,
#   'Region': 'Lolland',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Lolland'},
#  {'caseId': 'Journey55',
#   'HolidayType': 'Recreation',
#   'Price': 648,
#   'NumberOfPersons': 2,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Gasthaus Meier, Allgaeu'},
#  {'caseId': 'Journey56',
#   'HolidayType': 'Wandering',
#   'Price': 972,
#   'NumberOfPersons': 4,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Gasthaus Alpenland, Allgaeu'},
#  {'caseId': 'Journey57',
#   'HolidayType': 'Recreation',
#   'Price': 1060,
#   'NumberOfPersons': 3,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Alpspitz, Allgaeu'},
#  {'caseId': 'Journey58',
#   'HolidayType': 'Wandering',
#   'Price': 2110,
#   'NumberOfPersons': 3,
#   'Region': 'Allgaeu',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Alpspitz, Allgaeu'},
#  {'caseId': 'Journey59',
#   'HolidayType': 'Active',
#   'Price': 1835,
#   'NumberOfPersons': 2,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hofgut Kuernach, Allgaeu'},
#  {'caseId': 'Journey60',
#   'HolidayType': 'Wandering',
#   'Price': 951,
#   'NumberOfPersons': 2,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hofgut Kuernach, Allgaeu'},
#  {'caseId': 'Journey61',
#   'HolidayType': 'Recreation',
#   'Price': 794,
#   'NumberOfPersons': 4,
#   'Region': 'Allgaeu',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Allgaeu'},
#  {'caseId': 'Journey62',
#   'HolidayType': 'Active',
#   'Price': 814,
#   'NumberOfPersons': 6,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Allgaeu'},
#  {'caseId': 'Journey63',
#   'HolidayType': 'Wandering',
#   'Price': 1568,
#   'NumberOfPersons': 4,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Allgaeu'},
#  {'caseId': 'Journey64',
#   'HolidayType': 'Wandering',
#   'Price': 644,
#   'NumberOfPersons': 4,
#   'Region': 'Allgaeu',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Allgaeu'},
#  {'caseId': 'Journey65',
#   'HolidayType': 'Recreation',
#   'Price': 648,
#   'NumberOfPersons': 2,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Pension Blueml, Upper Bavaria'},
#  {'caseId': 'Journey66',
#   'HolidayType': 'Wandering',
#   'Price': 2232,
#   'NumberOfPersons': 3,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Pension Blueml, Upper Bavaria'},
#  {'caseId': 'Journey67',
#   'HolidayType': 'Recreation',
#   'Price': 2082,
#   'NumberOfPersons': 4,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#  {'caseId': 'Journey68',
#   'HolidayType': 'Recreation',
#   'Price': 5185,
#   'NumberOfPersons': 3,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 21,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#  {'caseId': 'Journey69',
#   'HolidayType': 'Active',
#   'Price': 2368,
#   'NumberOfPersons': 2,
#   'Region': 'Alps',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#  {'caseId': 'Journey70',
#   'HolidayType': 'Recreation',
#   'Price': 3758,
#   'NumberOfPersons': 2,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 21,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#  {'caseId': 'Journey71',
#   'HolidayType': 'Recreation',
#   'Price': 3135,
#   'NumberOfPersons': 3,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#  {'caseId': 'Journey72',
#   'HolidayType': 'Wandering',
#   'Price': 3762,
#   'NumberOfPersons': 4,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#  {'caseId': 'Journey73',
#   'HolidayType': 'Recreation',
#   'Price': 1254,
#   'NumberOfPersons': 4,
#   'Region': 'Alps',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey74',
#   'HolidayType': 'Recreation',
#   'Price': 814,
#   'NumberOfPersons': 6,
#   'Region': 'Alps',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey75',
#   'HolidayType': 'Recreation',
#   'Price': 1361,
#   'NumberOfPersons': 2,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey76',
#   'HolidayType': 'Recreation',
#   'Price': 1618,
#   'NumberOfPersons': 4,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey77',
#   'HolidayType': 'Recreation',
#   'Price': 1728,
#   'NumberOfPersons': 2,
#   'Region': 'Bavaria',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey78',
#   'HolidayType': 'Wandering',
#   'Price': 609,
#   'NumberOfPersons': 3,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey79',
#   'HolidayType': 'Wandering',
#   'Price': 1069,
#   'NumberOfPersons': 6,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey80',
#   'HolidayType': 'Wandering',
#   'Price': 684,
#   'NumberOfPersons': 4,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey81',
#   'HolidayType': 'Active',
#   'Price': 1328,
#   'NumberOfPersons': 4,
#   'Region': 'Bavaria',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey82',
#   'HolidayType': 'Active',
#   'Price': 779,
#   'NumberOfPersons': 2,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey83',
#   'HolidayType': 'Active',
#   'Price': 1639,
#   'NumberOfPersons': 5,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey84',
#   'HolidayType': 'Wandering',
#   'Price': 944,
#   'NumberOfPersons': 8,
#   'Region': 'Bavaria',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Upper Bavaria'},
#  {'caseId': 'Journey85',
#   'HolidayType': 'Wandering',
#   'Price': 758,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#  {'caseId': 'Journey86',
#   'HolidayType': 'Wandering',
#   'Price': 758,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#  {'caseId': 'Journey87',
#   'HolidayType': 'Recreation',
#   'Price': 1885,
#   'NumberOfPersons': 4,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#  {'caseId': 'Journey88',
#   'HolidayType': 'Recreation',
#   'Price': 758,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#  {'caseId': 'Journey89',
#   'HolidayType': 'Wandering',
#   'Price': 1828,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#  {'caseId': 'Journey90',
#   'HolidayType': 'Wandering',
#   'Price': 918,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#  {'caseId': 'Journey91',
#   'HolidayType': 'Wandering',
#   'Price': 2738,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 21,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#  {'caseId': 'Journey92',
#   'HolidayType': 'Recreation',
#   'Price': 1828,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Sporthotel, Erz Gebirge'},
#  {'caseId': 'Journey93',
#   'HolidayType': 'Recreation',
#   'Price': 918,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Sporthotel, Erz Gebirge'},
#  {'caseId': 'Journey94',
#   'HolidayType': 'Wandering',
#   'Price': 1580,
#   'NumberOfPersons': 4,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#  {'caseId': 'Journey95',
#   'HolidayType': 'Wandering',
#   'Price': 958,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#  {'caseId': 'Journey96',
#   'HolidayType': 'Wandering',
#   'Price': 2385,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#  {'caseId': 'Journey97',
#   'HolidayType': 'Recreation',
#   'Price': 1372,
#   'NumberOfPersons': 3,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Erz Gebirge'},
#  {'caseId': 'Journey98',
#   'HolidayType': 'Recreation',
#   'Price': 2188,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Erz Gebirge'},
#  {'caseId': 'Journey99',
#   'HolidayType': 'Active',
#   'Price': 1098,
#   'NumberOfPersons': 2,
#   'Region': 'ErzGebirge',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Erz Gebirge'},
#  {'caseId': 'Journey100',
#   'HolidayType': 'Recreation',
#   'Price': 478,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Brockenscheideck, Harz'},
#  {'caseId': 'Journey101',
#   'HolidayType': 'Wandering',
#   'Price': 948,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Brockenscheideck, Harz'},
#  {'caseId': 'Journey102',
#   'HolidayType': 'Recreation',
#   'Price': 1072,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldfrieden, Harz'},
#  {'caseId': 'Journey103',
#   'HolidayType': 'Recreation',
#   'Price': 1501,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldfrieden, Harz'},
#  {'caseId': 'Journey104',
#   'HolidayType': 'Recreation',
#   'Price': 1868,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldfrieden, Harz'},
#  {'caseId': 'Journey105',
#   'HolidayType': 'Wandering',
#   'Price': 1172,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldfrieden, Harz'},
#  {'caseId': 'Journey106',
#   'HolidayType': 'Recreation',
#   'Price': 1888,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hotel Maritim, Harz'},
#  {'caseId': 'Journey107',
#   'HolidayType': 'Recreation',
#   'Price': 1888,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hotel Maritim, Harz'},
#  {'caseId': 'Journey108',
#   'HolidayType': 'Wandering',
#   'Price': 3768,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'FiveStars',
#   'Hotel': 'Hotel Maritim, Harz'},
#  {'caseId': 'Journey109',
#   'HolidayType': 'Recreation',
#   'Price': 484,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Harz'},
#  {'caseId': 'Journey110',
#   'HolidayType': 'Recreation',
#   'Price': 374,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Harz'},
#  {'caseId': 'Journey111',
#   'HolidayType': 'Recreation',
#   'Price': 589,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Harz'},
#  {'caseId': 'Journey112',
#   'HolidayType': 'Wandering',
#   'Price': 719,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Harz'},
#  {'caseId': 'Journey113',
#   'HolidayType': 'Wandering',
#   'Price': 1248,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Harz'},
#  {'caseId': 'Journey114',
#   'HolidayType': 'Bathing',
#   'Price': 398,
#   'NumberOfPersons': 2,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'OneStar',
#   'Hotel': 'Pension Murra, North Sea'},
#  {'caseId': 'Journey115',
#   'HolidayType': 'Recreation',
#   'Price': 398,
#   'NumberOfPersons': 2,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'OneStar',
#   'Hotel': 'Pension Murra, North Sea'},
#  {'caseId': 'Journey116',
#   'HolidayType': 'Bathing',
#   'Price': 1348,
#   'NumberOfPersons': 3,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Pension Nina, North Sea'},
#  {'caseId': 'Journey117',
#   'HolidayType': 'Bathing',
#   'Price': 1348,
#   'NumberOfPersons': 2,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Pension Nina, North Sea'},
#  {'caseId': 'Journey118',
#   'HolidayType': 'Recreation',
#   'Price': 3228,
#   'NumberOfPersons': 2,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Silbermoeve, North Sea'},
#  {'caseId': 'Journey119',
#   'HolidayType': 'Recreation',
#   'Price': 1618,
#   'NumberOfPersons': 2,
#   'Region': 'NorthSea',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Silbermoeve, North Sea'},
#  {'caseId': 'Journey120',
#   'HolidayType': 'Bathing',
#   'Price': 719,
#   'NumberOfPersons': 4,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey121',
#   'HolidayType': 'Bathing',
#   'Price': 669,
#   'NumberOfPersons': 6,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey122',
#   'HolidayType': 'Bathing',
#   'Price': 2108,
#   'NumberOfPersons': 4,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey123',
#   'HolidayType': 'Recreation',
#   'Price': 579,
#   'NumberOfPersons': 4,
#   'Region': 'NorthSea',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey124',
#   'HolidayType': 'Recreation',
#   'Price': 664,
#   'NumberOfPersons': 5,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey125',
#   'HolidayType': 'Recreation',
#   'Price': 1138,
#   'NumberOfPersons': 4,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey126',
#   'HolidayType': 'Active',
#   'Price': 2198,
#   'NumberOfPersons': 3,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey127',
#   'HolidayType': 'Recreation',
#   'Price': 1044,
#   'NumberOfPersons': 6,
#   'Region': 'NorthSea',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat North Sea'},
#  {'caseId': 'Journey128',
#   'HolidayType': 'Active',
#   'Price': 719,
#   'NumberOfPersons': 3,
#   'Region': 'NorthSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Sylt'},
#  {'caseId': 'Journey129',
#   'HolidayType': 'Bathing',
#   'Price': 1828,
#   'NumberOfPersons': 2,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Stoertebeker, Zingst'},
#  {'caseId': 'Journey130',
#   'HolidayType': 'Bathing',
#   'Price': 918,
#   'NumberOfPersons': 3,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Stoertebeker, Zingst'},
#  {'caseId': 'Journey131',
#   'HolidayType': 'Recreation',
#   'Price': 918,
#   'NumberOfPersons': 2,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Am Leuchtturm, Warnemuende'},
#  {'caseId': 'Journey132',
#   'HolidayType': 'Recreation',
#   'Price': 1147,
#   'NumberOfPersons': 3,
#   'Region': 'BalticSea',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Am Leuchtturm, Warnemuende'},
#  {'caseId': 'Journey133',
#   'HolidayType': 'Bathing',
#   'Price': 1047,
#   'NumberOfPersons': 3,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Baltic, Usedom'},
#  {'caseId': 'Journey134',
#   'HolidayType': 'Bathing',
#   'Price': 2472,
#   'NumberOfPersons': 4,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Baltic, Usedom'},
#  {'caseId': 'Journey135',
#   'HolidayType': 'Recreation',
#   'Price': 2226,
#   'NumberOfPersons': 3,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'NobisHotel, Ruegen'},
#  {'caseId': 'Journey136',
#   'HolidayType': 'Bathing',
#   'Price': 1438,
#   'NumberOfPersons': 2,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Ostseehotel, Wustrow'},
#  {'caseId': 'Journey137',
#   'HolidayType': 'Active',
#   'Price': 1797,
#   'NumberOfPersons': 3,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Ostseehotel, Wustrow'},
#  {'caseId': 'Journey138',
#   'HolidayType': 'Bathing',
#   'Price': 1044,
#   'NumberOfPersons': 4,
#   'Region': 'BalticSea',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Baltic Sea'},
#  {'caseId': 'Journey139',
#   'HolidayType': 'Bathing',
#   'Price': 639,
#   'NumberOfPersons': 2,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Fehmarn'},
#  {'caseId': 'Journey140',
#   'HolidayType': 'Bathing',
#   'Price': 1818,
#   'NumberOfPersons': 2,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat, Ruegen'},
#  {'caseId': 'Journey141',
#   'HolidayType': 'Recreation',
#   'Price': 539,
#   'NumberOfPersons': 4,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Baltic Sea'},
#  {'caseId': 'Journey142',
#   'HolidayType': 'Recreation',
#   'Price': 709,
#   'NumberOfPersons': 6,
#   'Region': 'BalticSea',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Baltic Sea'},
#  {'caseId': 'Journey143',
#   'HolidayType': 'Active',
#   'Price': 994,
#   'NumberOfPersons': 4,
#   'Region': 'BalticSea',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Baltic Sea'},
#  {'caseId': 'Journey144',
#   'HolidayType': 'Wandering',
#   'Price': 547,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Hirschen, Black Forest'},
#  {'caseId': 'Journey145',
#   'HolidayType': 'Recreation',
#   'Price': 868,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Hirschen, Black Forest'},
#  {'caseId': 'Journey146',
#   'HolidayType': 'Wandering',
#   'Price': 907,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldwinkel, Black Forest'},
#  {'caseId': 'Journey147',
#   'HolidayType': 'Wandering',
#   'Price': 698,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldwinkel, Black Forest'},
#  {'caseId': 'Journey148',
#   'HolidayType': 'Wandering',
#   'Price': 738,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Kandel, Black Forest'},
#  {'caseId': 'Journey149',
#   'HolidayType': 'Recreation',
#   'Price': 922,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Kandel, Black Forest'},
#  {'caseId': 'Journey150',
#   'HolidayType': 'Wandering',
#   'Price': 3732,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Kurhotel, Black Forest'},
#  {'caseId': 'Journey151',
#   'HolidayType': 'Recreation',
#   'Price': 1138,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Kurhotel, Black Forest'},
#  {'caseId': 'Journey152',
#   'HolidayType': 'Wandering',
#   'Price': 449,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey153',
#   'HolidayType': 'Wandering',
#   'Price': 459,
#   'NumberOfPersons': 5,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey154',
#   'HolidayType': 'Wandering',
#   'Price': 1039,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey155',
#   'HolidayType': 'Wandering',
#   'Price': 2538,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey156',
#   'HolidayType': 'Recreation',
#   'Price': 1313,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey157',
#   'HolidayType': 'Recreation',
#   'Price': 904,
#   'NumberOfPersons': 6,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'October',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey158',
#   'HolidayType': 'Recreation',
#   'Price': 984,
#   'NumberOfPersons': 7,
#   'Region': 'BlackForest',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Black Forest'},
#  {'caseId': 'Journey159',
#   'HolidayType': 'Recreation',
#   'Price': 638,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Oberhof, Thuringia'},
#  {'caseId': 'Journey160',
#   'HolidayType': 'Recreation',
#   'Price': 922,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Oberhof, Thuringia'},
#  {'caseId': 'Journey161',
#   'HolidayType': 'Active',
#   'Price': 998,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Finsterbergen, Thuringia'},
#  {'caseId': 'Journey162',
#   'HolidayType': 'Wandering',
#   'Price': 2588,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Finsterbergen, Thuringia'},
#  {'caseId': 'Journey163',
#   'HolidayType': 'Wandering',
#   'Price': 1377,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Train',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Rennsteig, Thuringia'},
#  {'caseId': 'Journey164',
#   'HolidayType': 'Recreation',
#   'Price': 918,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Rennsteig, Thuringia'},
#  {'caseId': 'Journey165',
#   'HolidayType': 'Active',
#   'Price': 2285,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Rennsteig, Thuringia'},
#  {'caseId': 'Journey166',
#   'HolidayType': 'Recreation',
#   'Price': 2668,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'October',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey167',
#   'HolidayType': 'Active',
#   'Price': 1497,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey168',
#   'HolidayType': 'Active',
#   'Price': 2388,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey169',
#   'HolidayType': 'Recreation',
#   'Price': 589,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Thuringia'},
#  {'caseId': 'Journey170',
#   'HolidayType': 'Recreation',
#   'Price': 1128,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Train',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Thuringia'},
#  {'caseId': 'Journey171',
#   'HolidayType': 'Recreation',
#   'Price': 589,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Thuringia'},
#  {'caseId': 'Journey172',
#   'HolidayType': 'Recreation',
#   'Price': 1148,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Thuringia'},
#  {'caseId': 'Journey173',
#   'HolidayType': 'Wandering',
#   'Price': 574,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Thuringia'},
#  {'caseId': 'Journey174',
#   'HolidayType': 'Bathing',
#   'Price': 858,
#   'NumberOfPersons': 4,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey175',
#   'HolidayType': 'Bathing',
#   'Price': 2078,
#   'NumberOfPersons': 4,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey176',
#   'HolidayType': 'Bathing',
#   'Price': 4718,
#   'NumberOfPersons': 7,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey177',
#   'HolidayType': 'Bathing',
#   'Price': 1698,
#   'NumberOfPersons': 4,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey178',
#   'HolidayType': 'Bathing',
#   'Price': 649,
#   'NumberOfPersons': 6,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'September',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey179',
#   'HolidayType': 'Bathing',
#   'Price': 394,
#   'NumberOfPersons': 3,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey180',
#   'HolidayType': 'Bathing',
#   'Price': 1289,
#   'NumberOfPersons': 5,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey181',
#   'HolidayType': 'Bathing',
#   'Price': 879,
#   'NumberOfPersons': 4,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey182',
#   'HolidayType': 'Bathing',
#   'Price': 1347,
#   'NumberOfPersons': 3,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 21,
#   'Season': 'May',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey183',
#   'HolidayType': 'Active',
#   'Price': 838,
#   'NumberOfPersons': 5,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey184',
#   'HolidayType': 'Active',
#   'Price': 1938,
#   'NumberOfPersons': 6,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey185',
#   'HolidayType': 'Active',
#   'Price': 849,
#   'NumberOfPersons': 6,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey186',
#   'HolidayType': 'Active',
#   'Price': 1204,
#   'NumberOfPersons': 8,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'June',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey187',
#   'HolidayType': 'Recreation',
#   'Price': 2878,
#   'NumberOfPersons': 8,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'July',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey188',
#   'HolidayType': 'Recreation',
#   'Price': 2187,
#   'NumberOfPersons': 2,
#   'Region': 'Atlantic',
#   'Transportation': 'Car',
#   'Duration': 21,
#   'Season': 'August',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Atlantik, France'},
#  {'caseId': 'Journey189',
#   'HolidayType': 'Bathing',
#   'Price': 519,
# ...
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Aparthotel Bocksberg, Harz'},
#  {'caseId': 'Journey941',
#   'HolidayType': 'Recreation',
#   'Price': 1910,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Aparthotel Bocksberg, Harz'},
#  {'caseId': 'Journey942',
#   'HolidayType': 'Wandering',
#   'Price': 1648,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Aparthotel Bocksberg, Harz'},
#  {'caseId': 'Journey943',
#   'HolidayType': 'Skiing',
#   'Price': 2007,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Aparthotel Bocksberg, Harz'},
#  {'caseId': 'Journey944',
#   'HolidayType': 'Recreation',
#   'Price': 2368,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 10,
#   'Season': 'December',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Travelhotel Waldfrieden, Harz'},
#  {'caseId': 'Journey945',
#   'HolidayType': 'Recreation',
#   'Price': 1485,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Travelhotel Waldfrieden, Harz'},
#  {'caseId': 'Journey946',
#   'HolidayType': 'Wandering',
#   'Price': 1298,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Travelhotel Waldfrieden, Harz'},
#  {'caseId': 'Journey947',
#   'HolidayType': 'Active',
#   'Price': 1782,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Travelhotel Waldfrieden, Harz'},
#  {'caseId': 'Journey948',
#   'HolidayType': 'Recreation',
#   'Price': 2007,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Harzquell, Harz'},
#  {'caseId': 'Journey949',
#   'HolidayType': 'Wandering',
#   'Price': 1168,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Harzquell, Harz'},
#  {'caseId': 'Journey950',
#   'HolidayType': 'Skiing',
#   'Price': 1460,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Harzquell, Harz'},
#  {'caseId': 'Journey951',
#   'HolidayType': 'Recreation',
#   'Price': 1522,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#  {'caseId': 'Journey952',
#   'HolidayType': 'Recreation',
#   'Price': 1482,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#  {'caseId': 'Journey953',
#   'HolidayType': 'Skiing',
#   'Price': 1235,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#  {'caseId': 'Journey954',
#   'HolidayType': 'Wandering',
#   'Price': 599,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'November',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Panoramic, Harz'},
#  {'caseId': 'Journey955',
#   'HolidayType': 'Recreation',
#   'Price': 679,
#   'NumberOfPersons': 5,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Panoramic, Harz'},
#  {'caseId': 'Journey956',
#   'HolidayType': 'Recreation',
#   'Price': 419,
#   'NumberOfPersons': 2,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Ferienpark, Harz'},
#  {'caseId': 'Journey957',
#   'HolidayType': 'Wandering',
#   'Price': 1114,
#   'NumberOfPersons': 4,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 10,
#   'Season': 'December',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Ferienpark, Harz'},
#  {'caseId': 'Journey958',
#   'HolidayType': 'Skiing',
#   'Price': 324,
#   'NumberOfPersons': 3,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Teichtal, Harz'},
#  {'caseId': 'Journey959',
#   'HolidayType': 'Skiing',
#   'Price': 499,
#   'NumberOfPersons': 6,
#   'Region': 'Harz',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Teichtal, Harz'},
#  {'caseId': 'Journey960',
#   'HolidayType': 'Wandering',
#   'Price': 1227,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Hirschen, Black Forest'},
#  {'caseId': 'Journey961',
#   'HolidayType': 'Active',
#   'Price': 748,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Hirschen, Black Forest'},
#  {'caseId': 'Journey962',
#   'HolidayType': 'Skiing',
#   'Price': 1735,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Treff-Hotel, Black Forest'},
#  {'caseId': 'Journey963',
#   'HolidayType': 'Wandering',
#   'Price': 2768,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'March',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Treff-Hotel, Black Forest'},
#  {'caseId': 'Journey964',
#   'HolidayType': 'Recreation',
#   'Price': 1737,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Kandel, Black Forest'},
#  {'caseId': 'Journey965',
#   'HolidayType': 'Wandering',
#   'Price': 818,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Kandel, Black Forest'},
#  {'caseId': 'Journey966',
#   'HolidayType': 'Recreation',
#   'Price': 2322,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 10,
#   'Season': 'December',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Mummelsee, Black Forest'},
#  {'caseId': 'Journey967',
#   'HolidayType': 'Skiing',
#   'Price': 1158,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Mummelsee, Black Forest'},
#  {'caseId': 'Journey968',
#   'HolidayType': 'Active',
#   'Price': 1008,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldwinkel, Black Forest'},
#  {'caseId': 'Journey969',
#   'HolidayType': 'Recreation',
#   'Price': 1260,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Waldwinkel, Black Forest'},
#  {'caseId': 'Journey970',
#   'HolidayType': 'Wandering',
#   'Price': 1257,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Gasthof Hochkopfhaus, Black Forest'},
#  {'caseId': 'Journey971',
#   'HolidayType': 'Skiing',
#   'Price': 838,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Gasthof Hochkopfhaus, Black Forest'},
#  {'caseId': 'Journey972',
#   'HolidayType': 'Recreation',
#   'Price': 897,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Landgasthof Schuetzen, Black Forest'},
#  {'caseId': 'Journey973',
#   'HolidayType': 'Wandering',
#   'Price': 688,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 6,
#   'Season': 'December',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Landgasthof Schuetzen, Black Forest'},
#  {'caseId': 'Journey974',
#   'HolidayType': 'Active',
#   'Price': 454,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Ferienpark Black Forest'},
#  {'caseId': 'Journey975',
#   'HolidayType': 'Active',
#   'Price': 514,
#   'NumberOfPersons': 6,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Ferienpark Black Forest'},
#  {'caseId': 'Journey976',
#   'HolidayType': 'Recreation',
#   'Price': 459,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwarzwaldgrund'},
#  {'caseId': 'Journey977',
#   'HolidayType': 'Recreation',
#   'Price': 1068,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwarzwaldgrund'},
#  {'caseId': 'Journey978',
#   'HolidayType': 'Skiing',
#   'Price': 549,
#   'NumberOfPersons': 6,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Sonnenrain, Black Forest'},
#  {'caseId': 'Journey979',
#   'HolidayType': 'Recreation',
#   'Price': 679,
#   'NumberOfPersons': 2,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwarzwaldblick'},
#  {'caseId': 'Journey980',
#   'HolidayType': 'Recreation',
#   'Price': 599,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwarzwaldblick'},
#  {'caseId': 'Journey981',
#   'HolidayType': 'Skiing',
#   'Price': 464,
#   'NumberOfPersons': 3,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwiezer Hof, Black Forest'},
#  {'caseId': 'Journey982',
#   'HolidayType': 'Wandering',
#   'Price': 1033,
#   'NumberOfPersons': 5,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'March',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schwiezer Hof, Black Forest'},
#  {'caseId': 'Journey983',
#   'HolidayType': 'Recreation',
#   'Price': 989,
#   'NumberOfPersons': 4,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Panorama-Blick, Black Forest'},
#  {'caseId': 'Journey984',
#   'HolidayType': 'Wandering',
#   'Price': 839,
#   'NumberOfPersons': 6,
#   'Region': 'BlackForest',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Panorama-Blick, Black Forest'},
#  {'caseId': 'Journey985',
#   'HolidayType': 'Wandering',
#   'Price': 1672,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Friedrichroda, Thuringia'},
#  {'caseId': 'Journey986',
#   'HolidayType': 'Recreation',
#   'Price': 1178,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Friedrichroda, Thuringia'},
#  {'caseId': 'Journey987',
#   'HolidayType': 'Active',
#   'Price': 4092,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'February',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Finsterbergen, Thuringia'},
#  {'caseId': 'Journey988',
#   'HolidayType': 'Wandering',
#   'Price': 1368,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Hotel Finsterbergen, Thuringia'},
#  {'caseId': 'Journey989',
#   'HolidayType': 'Wandering',
#   'Price': 1104,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Schoene Aussicht, Thuringia'},
#  {'caseId': 'Journey990',
#   'HolidayType': 'Skiing',
#   'Price': 883,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Schoene Aussicht, Thuringia'},
#  {'caseId': 'Journey991',
#   'HolidayType': 'Recreation',
#   'Price': 688,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Oberhof, Thuringia'},
#  {'caseId': 'Journey992',
#   'HolidayType': 'Wandering',
#   'Price': 1773,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'November',
#   'Accomodation': 'ThreeStars',
#   'Hotel': 'Berghotel Oberhof, Thuringia'},
#  {'caseId': 'Journey993',
#   'HolidayType': 'Wandering',
#   'Price': 1138,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'January',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey994',
#   'HolidayType': 'Recreation',
#   'Price': 1647,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey995',
#   'HolidayType': 'Skiing',
#   'Price': 1977,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'FourStars',
#   'Hotel': 'Hotel Panorama, Thuringia'},
#  {'caseId': 'Journey996',
#   'HolidayType': 'Wandering',
#   'Price': 1294,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 14,
#   'Season': 'January',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Am Schuetzenberg, Thuringia'},
#  {'caseId': 'Journey997',
#   'HolidayType': 'Recreation',
#   'Price': 785,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'December',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Am Schuetzenberg, Thuringia'},
#  {'caseId': 'Journey998',
#   'HolidayType': 'Active',
#   'Price': 987,
#   'NumberOfPersons': 4,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Frankenwald, Thuringia'},
#  {'caseId': 'Journey999',
#   'HolidayType': 'Wandering',
#   'Price': 598,
#   'NumberOfPersons': 2,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'March',
#   'Accomodation': 'TwoStars',
#   'Hotel': 'Hotel Frankenwald, Thuringia'},
#  {'caseId': 'Journey1000',
#   'HolidayType': 'Wandering',
#   'Price': 389,
#   'NumberOfPersons': 3,
#   'Region': 'Thuringia',
#   'Transportation': 'Car',
#   'Duration': 7,
#   'Season': 'February',
#   'Accomodation': 'HolidayFlat',
#   'Hotel': 'H.Flat Schmeheim, Thuringia'},
#  ...]

# %%
df.columns
# Out:
# Index(['caseId', 'HolidayType', 'Price', 'NumberOfPersons', 'Region',
#        'Transportation', 'Duration', 'Season', 'Accomodation', 'Hotel'],
#       dtype='object')

# %%
dataFile = dict(
    description = "[Travel Agent Case Base](https://www.cs.auckland.ac.nz/research/groups/ai-cbr/cases.html)", 
    attributes = {
        'caseId': "string",
        'HolidayType': "string",
        'NumberOfPersons': "number",
        'Region': "string",
        'Transportation': "string",
        'Duration': "number",
        'Season': "string",
        'Accomodation': "string",
        'Hotel': "string",
        'Price': "number"
    },
    id= "caseId",
    data= content
)
dataFile
# Out:
# {'description': '[Travel Agent Case Base](https://www.cs.auckland.ac.nz/research/groups/ai-cbr/cases.html)',
#  'attributes': {'caseId': 'string',
#   'HolidayType': 'string',
#   'NumberOfPersons': 'number',
#   'Region': 'string',
#   'Transportation': 'string',
#   'Duration': 'number',
#   'Season': 'string',
#   'Accomodation': 'string',
#   'Hotel': 'string',
#   'Price': 'number'},
#  'id': 'caseId',
#  'data': [{'caseId': 'Journey1',
#    'HolidayType': 'Bathing',
#    'Price': 2498,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'April',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel White House, Egypt'},
#   {'caseId': 'Journey2',
#    'HolidayType': 'Bathing',
#    'Price': 3066,
#    'NumberOfPersons': 3,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 21,
#    'Season': 'May',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel White House, Egypt'},
#   {'caseId': 'Journey3',
#    'HolidayType': 'Active',
#    'Price': 2778,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Geisum, Egypt'},
#   {'caseId': 'Journey4',
#    'HolidayType': 'Bathing',
#    'Price': 3195,
#    'NumberOfPersons': 3,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Al Mashrabia, Egypt'},
#   {'caseId': 'Journey5',
#    'HolidayType': 'Bathing',
#    'Price': 3158,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Al Mashrabia, Egypt'},
#   {'caseId': 'Journey6',
#    'HolidayType': 'Active',
#    'Price': 3318,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'October',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Al Mashrabia, Egypt'},
#   {'caseId': 'Journey7',
#    'HolidayType': 'Bathing',
#    'Price': 2458,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Winter Palace, Egypt'},
#   {'caseId': 'Journey8',
#    'HolidayType': 'Active',
#    'Price': 2649,
#    'NumberOfPersons': 3,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Winter Palace, Egypt'},
#   {'caseId': 'Journey9',
#    'HolidayType': 'Education',
#    'Price': 4638,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 21,
#    'Season': 'April',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Anlage Arabia Beach, Egypt'},
#   {'caseId': 'Journey10',
#    'HolidayType': 'Education',
#    'Price': 3738,
#    'NumberOfPersons': 2,
#    'Region': 'Egypt',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'October',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Anlage Arabia Beach, Egypt'},
#   {'caseId': 'Journey11',
#    'HolidayType': 'City',
#    'Price': 1978,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'April',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Victoria, Cairo'},
#   {'caseId': 'Journey12',
#    'HolidayType': 'City',
#    'Price': 1898,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Victoria, Cairo'},
#   {'caseId': 'Journey13',
#    'HolidayType': 'City',
#    'Price': 2158,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Victoria, Cairo'},
#   {'caseId': 'Journey14',
#    'HolidayType': 'City',
#    'Price': 1898,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Victoria, Cairo'},
#   {'caseId': 'Journey15',
#    'HolidayType': 'City',
#    'Price': 1154,
#    'NumberOfPersons': 1,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'October',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel New Marwa Palace, Cairo'},
#   {'caseId': 'Journey16',
#    'HolidayType': 'City',
#    'Price': 2308,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'April',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel New Marwa Palace, Cairo'},
#   {'caseId': 'Journey17',
#    'HolidayType': 'City',
#    'Price': 2658,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel New Marwa Palace, Cairo'},
#   {'caseId': 'Journey18',
#    'HolidayType': 'City',
#    'Price': 1269,
#    'NumberOfPersons': 1,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel New Marwa Palace, Cairo'},
#   {'caseId': 'Journey19',
#    'HolidayType': 'City',
#    'Price': 2608,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hotel Moevenpick, Cairo'},
#   {'caseId': 'Journey20',
#    'HolidayType': 'City',
#    'Price': 2468,
#    'NumberOfPersons': 2,
#    'Region': 'Cairo',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hotel Moevenpick, Cairo'},
#   {'caseId': 'Journey21',
#    'HolidayType': 'Recreation',
#    'Price': 1568,
#    'NumberOfPersons': 2,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Ostend, Belgium'},
#   {'caseId': 'Journey22',
#    'HolidayType': 'Active',
#    'Price': 798,
#    'NumberOfPersons': 3,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Ostend, Belgium'},
#   {'caseId': 'Journey23',
#    'HolidayType': 'Recreation',
#    'Price': 978,
#    'NumberOfPersons': 3,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Acces Hotel Mercure, Belgium'},
#   {'caseId': 'Journey24',
#    'HolidayType': 'Recreation',
#    'Price': 978,
#    'NumberOfPersons': 2,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Acces Hotel Mercure, Belgium'},
#   {'caseId': 'Journey25',
#    'HolidayType': 'Active',
#    'Price': 1448,
#    'NumberOfPersons': 3,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Belgium'},
#   {'caseId': 'Journey26',
#    'HolidayType': 'Recreation',
#    'Price': 1638,
#    'NumberOfPersons': 4,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Belgium'},
#   {'caseId': 'Journey27',
#    'HolidayType': 'Recreation',
#    'Price': 1079,
#    'NumberOfPersons': 4,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Belgium'},
#   {'caseId': 'Journey28',
#    'HolidayType': 'Bathing',
#    'Price': 499,
#    'NumberOfPersons': 4,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 3,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Belgium'},
#   {'caseId': 'Journey29',
#    'HolidayType': 'Bathing',
#    'Price': 399,
#    'NumberOfPersons': 6,
#    'Region': 'Belgium',
#    'Transportation': 'Car',
#    'Duration': 3,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Belgium'},
#   {'caseId': 'Journey30',
#    'HolidayType': 'Recreation',
#    'Price': 1928,
#    'NumberOfPersons': 2,
#    'Region': 'Belgium',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Acces Hotel Mercure, Belgium'},
#   {'caseId': 'Journey31',
#    'HolidayType': 'Bathing',
#    'Price': 1598,
#    'NumberOfPersons': 2,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Amfibia, Sunny Beach'},
#   {'caseId': 'Journey32',
#    'HolidayType': 'Bathing',
#    'Price': 2043,
#    'NumberOfPersons': 3,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Hemus, Sunny Beach'},
#   {'caseId': 'Journey33',
#    'HolidayType': 'Bathing',
#    'Price': 1658,
#    'NumberOfPersons': 4,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Raliza, Albena'},
#   {'caseId': 'Journey34',
#    'HolidayType': 'Bathing',
#    'Price': 1558,
#    'NumberOfPersons': 2,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Phoenix, Sunny Beach'},
#   {'caseId': 'Journey35',
#    'HolidayType': 'Active',
#    'Price': 1718,
#    'NumberOfPersons': 2,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Nessebar, Sunny Beach'},
#   {'caseId': 'Journey36',
#    'HolidayType': 'Bathing',
#    'Price': 1383,
#    'NumberOfPersons': 3,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Gergana, Albena'},
#   {'caseId': 'Journey37',
#    'HolidayType': 'Bathing',
#    'Price': 3628,
#    'NumberOfPersons': 4,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 21,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Orlav, Albena'},
#   {'caseId': 'Journey38',
#    'HolidayType': 'Active',
#    'Price': 2739,
#    'NumberOfPersons': 3,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Burgas, Sunny Beach'},
#   {'caseId': 'Journey39',
#    'HolidayType': 'Bathing',
#    'Price': 2399,
#    'NumberOfPersons': 2,
#    'Region': 'Bulgaria',
#    'Transportation': 'Plane',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Grandhotel Varna, Albena'},
#   {'caseId': 'Journey40',
#    'HolidayType': 'Bathing',
#    'Price': 2273,
#    'NumberOfPersons': 3,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey41',
#    'HolidayType': 'Bathing',
#    'Price': 1729,
#    'NumberOfPersons': 5,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey42',
#    'HolidayType': 'Bathing',
#    'Price': 1389,
#    'NumberOfPersons': 4,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey43',
#    'HolidayType': 'Recreation',
#    'Price': 968,
#    'NumberOfPersons': 6,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'April',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey44',
#    'HolidayType': 'Recreation',
#    'Price': 489,
#    'NumberOfPersons': 6,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey45',
#    'HolidayType': 'Recreation',
#    'Price': 489,
#    'NumberOfPersons': 6,
#    'Region': 'Bornholm',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Bornholm'},
#   {'caseId': 'Journey46',
#    'HolidayType': 'Bathing',
#    'Price': 2838,
#    'NumberOfPersons': 4,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Fano'},
#   {'caseId': 'Journey47',
#    'HolidayType': 'Bathing',
#    'Price': 1399,
#    'NumberOfPersons': 6,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Fano'},
#   {'caseId': 'Journey48',
#    'HolidayType': 'Recreation',
#    'Price': 958,
#    'NumberOfPersons': 6,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Fano'},
#   {'caseId': 'Journey49',
#    'HolidayType': 'Recreation',
#    'Price': 579,
#    'NumberOfPersons': 3,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Romo'},
#   {'caseId': 'Journey50',
#    'HolidayType': 'Recreation',
#    'Price': 789,
#    'NumberOfPersons': 5,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Romo'},
#   {'caseId': 'Journey51',
#    'HolidayType': 'Recreation',
#    'Price': 2839,
#    'NumberOfPersons': 10,
#    'Region': 'Fano',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Romo'},
#   {'caseId': 'Journey52',
#    'HolidayType': 'Bathing',
#    'Price': 629,
#    'NumberOfPersons': 6,
#    'Region': 'Lolland',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Lolland'},
#   {'caseId': 'Journey53',
#    'HolidayType': 'Bathing',
#    'Price': 1598,
#    'NumberOfPersons': 4,
#    'Region': 'Lolland',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Lolland'},
#   {'caseId': 'Journey54',
#    'HolidayType': 'Recreation',
#    'Price': 429,
#    'NumberOfPersons': 8,
#    'Region': 'Lolland',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Lolland'},
#   {'caseId': 'Journey55',
#    'HolidayType': 'Recreation',
#    'Price': 648,
#    'NumberOfPersons': 2,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Gasthaus Meier, Allgaeu'},
#   {'caseId': 'Journey56',
#    'HolidayType': 'Wandering',
#    'Price': 972,
#    'NumberOfPersons': 4,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Gasthaus Alpenland, Allgaeu'},
#   {'caseId': 'Journey57',
#    'HolidayType': 'Recreation',
#    'Price': 1060,
#    'NumberOfPersons': 3,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Alpspitz, Allgaeu'},
#   {'caseId': 'Journey58',
#    'HolidayType': 'Wandering',
#    'Price': 2110,
#    'NumberOfPersons': 3,
#    'Region': 'Allgaeu',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Alpspitz, Allgaeu'},
#   {'caseId': 'Journey59',
#    'HolidayType': 'Active',
#    'Price': 1835,
#    'NumberOfPersons': 2,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hofgut Kuernach, Allgaeu'},
#   {'caseId': 'Journey60',
#    'HolidayType': 'Wandering',
#    'Price': 951,
#    'NumberOfPersons': 2,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hofgut Kuernach, Allgaeu'},
#   {'caseId': 'Journey61',
#    'HolidayType': 'Recreation',
#    'Price': 794,
#    'NumberOfPersons': 4,
#    'Region': 'Allgaeu',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Allgaeu'},
#   {'caseId': 'Journey62',
#    'HolidayType': 'Active',
#    'Price': 814,
#    'NumberOfPersons': 6,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Allgaeu'},
#   {'caseId': 'Journey63',
#    'HolidayType': 'Wandering',
#    'Price': 1568,
#    'NumberOfPersons': 4,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Allgaeu'},
#   {'caseId': 'Journey64',
#    'HolidayType': 'Wandering',
#    'Price': 644,
#    'NumberOfPersons': 4,
#    'Region': 'Allgaeu',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Allgaeu'},
#   {'caseId': 'Journey65',
#    'HolidayType': 'Recreation',
#    'Price': 648,
#    'NumberOfPersons': 2,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Pension Blueml, Upper Bavaria'},
#   {'caseId': 'Journey66',
#    'HolidayType': 'Wandering',
#    'Price': 2232,
#    'NumberOfPersons': 3,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Pension Blueml, Upper Bavaria'},
#   {'caseId': 'Journey67',
#    'HolidayType': 'Recreation',
#    'Price': 2082,
#    'NumberOfPersons': 4,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#   {'caseId': 'Journey68',
#    'HolidayType': 'Recreation',
#    'Price': 5185,
#    'NumberOfPersons': 3,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 21,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#   {'caseId': 'Journey69',
#    'HolidayType': 'Active',
#    'Price': 2368,
#    'NumberOfPersons': 2,
#    'Region': 'Alps',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Chiemgauer Hof, Upper Bavaria'},
#   {'caseId': 'Journey70',
#    'HolidayType': 'Recreation',
#    'Price': 3758,
#    'NumberOfPersons': 2,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 21,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#   {'caseId': 'Journey71',
#    'HolidayType': 'Recreation',
#    'Price': 3135,
#    'NumberOfPersons': 3,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#   {'caseId': 'Journey72',
#    'HolidayType': 'Wandering',
#    'Price': 3762,
#    'NumberOfPersons': 4,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Zur Post, Upper Bavaria'},
#   {'caseId': 'Journey73',
#    'HolidayType': 'Recreation',
#    'Price': 1254,
#    'NumberOfPersons': 4,
#    'Region': 'Alps',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey74',
#    'HolidayType': 'Recreation',
#    'Price': 814,
#    'NumberOfPersons': 6,
#    'Region': 'Alps',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey75',
#    'HolidayType': 'Recreation',
#    'Price': 1361,
#    'NumberOfPersons': 2,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey76',
#    'HolidayType': 'Recreation',
#    'Price': 1618,
#    'NumberOfPersons': 4,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey77',
#    'HolidayType': 'Recreation',
#    'Price': 1728,
#    'NumberOfPersons': 2,
#    'Region': 'Bavaria',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey78',
#    'HolidayType': 'Wandering',
#    'Price': 609,
#    'NumberOfPersons': 3,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey79',
#    'HolidayType': 'Wandering',
#    'Price': 1069,
#    'NumberOfPersons': 6,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey80',
#    'HolidayType': 'Wandering',
#    'Price': 684,
#    'NumberOfPersons': 4,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey81',
#    'HolidayType': 'Active',
#    'Price': 1328,
#    'NumberOfPersons': 4,
#    'Region': 'Bavaria',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey82',
#    'HolidayType': 'Active',
#    'Price': 779,
#    'NumberOfPersons': 2,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey83',
#    'HolidayType': 'Active',
#    'Price': 1639,
#    'NumberOfPersons': 5,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey84',
#    'HolidayType': 'Wandering',
#    'Price': 944,
#    'NumberOfPersons': 8,
#    'Region': 'Bavaria',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Upper Bavaria'},
#   {'caseId': 'Journey85',
#    'HolidayType': 'Wandering',
#    'Price': 758,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#   {'caseId': 'Journey86',
#    'HolidayType': 'Wandering',
#    'Price': 758,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#   {'caseId': 'Journey87',
#    'HolidayType': 'Recreation',
#    'Price': 1885,
#    'NumberOfPersons': 4,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#   {'caseId': 'Journey88',
#    'HolidayType': 'Recreation',
#    'Price': 758,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Wolfsgruener Schloss, Erz Gebirge'},
#   {'caseId': 'Journey89',
#    'HolidayType': 'Wandering',
#    'Price': 1828,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#   {'caseId': 'Journey90',
#    'HolidayType': 'Wandering',
#    'Price': 918,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#   {'caseId': 'Journey91',
#    'HolidayType': 'Wandering',
#    'Price': 2738,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 21,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Am Fichtelberg, Erz Gebirge'},
#   {'caseId': 'Journey92',
#    'HolidayType': 'Recreation',
#    'Price': 1828,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Sporthotel, Erz Gebirge'},
#   {'caseId': 'Journey93',
#    'HolidayType': 'Recreation',
#    'Price': 918,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Sporthotel, Erz Gebirge'},
#   {'caseId': 'Journey94',
#    'HolidayType': 'Wandering',
#    'Price': 1580,
#    'NumberOfPersons': 4,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#   {'caseId': 'Journey95',
#    'HolidayType': 'Wandering',
#    'Price': 958,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#   {'caseId': 'Journey96',
#    'HolidayType': 'Wandering',
#    'Price': 2385,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Kur- und Sporthotel, Erz Gebirge'},
#   {'caseId': 'Journey97',
#    'HolidayType': 'Recreation',
#    'Price': 1372,
#    'NumberOfPersons': 3,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Erz Gebirge'},
#   {'caseId': 'Journey98',
#    'HolidayType': 'Recreation',
#    'Price': 2188,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Erz Gebirge'},
#   {'caseId': 'Journey99',
#    'HolidayType': 'Active',
#    'Price': 1098,
#    'NumberOfPersons': 2,
#    'Region': 'ErzGebirge',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Erz Gebirge'},
#   {'caseId': 'Journey100',
#    'HolidayType': 'Recreation',
#    'Price': 478,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Brockenscheideck, Harz'},
#   {'caseId': 'Journey101',
#    'HolidayType': 'Wandering',
#    'Price': 948,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Brockenscheideck, Harz'},
#   {'caseId': 'Journey102',
#    'HolidayType': 'Recreation',
#    'Price': 1072,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldfrieden, Harz'},
#   {'caseId': 'Journey103',
#    'HolidayType': 'Recreation',
#    'Price': 1501,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldfrieden, Harz'},
#   {'caseId': 'Journey104',
#    'HolidayType': 'Recreation',
#    'Price': 1868,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldfrieden, Harz'},
#   {'caseId': 'Journey105',
#    'HolidayType': 'Wandering',
#    'Price': 1172,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldfrieden, Harz'},
#   {'caseId': 'Journey106',
#    'HolidayType': 'Recreation',
#    'Price': 1888,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hotel Maritim, Harz'},
#   {'caseId': 'Journey107',
#    'HolidayType': 'Recreation',
#    'Price': 1888,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hotel Maritim, Harz'},
#   {'caseId': 'Journey108',
#    'HolidayType': 'Wandering',
#    'Price': 3768,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'FiveStars',
#    'Hotel': 'Hotel Maritim, Harz'},
#   {'caseId': 'Journey109',
#    'HolidayType': 'Recreation',
#    'Price': 484,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Harz'},
#   {'caseId': 'Journey110',
#    'HolidayType': 'Recreation',
#    'Price': 374,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Harz'},
#   {'caseId': 'Journey111',
#    'HolidayType': 'Recreation',
#    'Price': 589,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Harz'},
#   {'caseId': 'Journey112',
#    'HolidayType': 'Wandering',
#    'Price': 719,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Harz'},
#   {'caseId': 'Journey113',
#    'HolidayType': 'Wandering',
#    'Price': 1248,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Harz'},
#   {'caseId': 'Journey114',
#    'HolidayType': 'Bathing',
#    'Price': 398,
#    'NumberOfPersons': 2,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'OneStar',
#    'Hotel': 'Pension Murra, North Sea'},
#   {'caseId': 'Journey115',
#    'HolidayType': 'Recreation',
#    'Price': 398,
#    'NumberOfPersons': 2,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'OneStar',
#    'Hotel': 'Pension Murra, North Sea'},
#   {'caseId': 'Journey116',
#    'HolidayType': 'Bathing',
#    'Price': 1348,
#    'NumberOfPersons': 3,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Pension Nina, North Sea'},
#   {'caseId': 'Journey117',
#    'HolidayType': 'Bathing',
#    'Price': 1348,
#    'NumberOfPersons': 2,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Pension Nina, North Sea'},
#   {'caseId': 'Journey118',
#    'HolidayType': 'Recreation',
#    'Price': 3228,
#    'NumberOfPersons': 2,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Silbermoeve, North Sea'},
#   {'caseId': 'Journey119',
#    'HolidayType': 'Recreation',
#    'Price': 1618,
#    'NumberOfPersons': 2,
#    'Region': 'NorthSea',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Silbermoeve, North Sea'},
#   {'caseId': 'Journey120',
#    'HolidayType': 'Bathing',
#    'Price': 719,
#    'NumberOfPersons': 4,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey121',
#    'HolidayType': 'Bathing',
#    'Price': 669,
#    'NumberOfPersons': 6,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey122',
#    'HolidayType': 'Bathing',
#    'Price': 2108,
#    'NumberOfPersons': 4,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey123',
#    'HolidayType': 'Recreation',
#    'Price': 579,
#    'NumberOfPersons': 4,
#    'Region': 'NorthSea',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey124',
#    'HolidayType': 'Recreation',
#    'Price': 664,
#    'NumberOfPersons': 5,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey125',
#    'HolidayType': 'Recreation',
#    'Price': 1138,
#    'NumberOfPersons': 4,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey126',
#    'HolidayType': 'Active',
#    'Price': 2198,
#    'NumberOfPersons': 3,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey127',
#    'HolidayType': 'Recreation',
#    'Price': 1044,
#    'NumberOfPersons': 6,
#    'Region': 'NorthSea',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat North Sea'},
#   {'caseId': 'Journey128',
#    'HolidayType': 'Active',
#    'Price': 719,
#    'NumberOfPersons': 3,
#    'Region': 'NorthSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Sylt'},
#   {'caseId': 'Journey129',
#    'HolidayType': 'Bathing',
#    'Price': 1828,
#    'NumberOfPersons': 2,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Stoertebeker, Zingst'},
#   {'caseId': 'Journey130',
#    'HolidayType': 'Bathing',
#    'Price': 918,
#    'NumberOfPersons': 3,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Stoertebeker, Zingst'},
#   {'caseId': 'Journey131',
#    'HolidayType': 'Recreation',
#    'Price': 918,
#    'NumberOfPersons': 2,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Am Leuchtturm, Warnemuende'},
#   {'caseId': 'Journey132',
#    'HolidayType': 'Recreation',
#    'Price': 1147,
#    'NumberOfPersons': 3,
#    'Region': 'BalticSea',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Am Leuchtturm, Warnemuende'},
#   {'caseId': 'Journey133',
#    'HolidayType': 'Bathing',
#    'Price': 1047,
#    'NumberOfPersons': 3,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Baltic, Usedom'},
#   {'caseId': 'Journey134',
#    'HolidayType': 'Bathing',
#    'Price': 2472,
#    'NumberOfPersons': 4,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Baltic, Usedom'},
#   {'caseId': 'Journey135',
#    'HolidayType': 'Recreation',
#    'Price': 2226,
#    'NumberOfPersons': 3,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'NobisHotel, Ruegen'},
#   {'caseId': 'Journey136',
#    'HolidayType': 'Bathing',
#    'Price': 1438,
#    'NumberOfPersons': 2,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Ostseehotel, Wustrow'},
#   {'caseId': 'Journey137',
#    'HolidayType': 'Active',
#    'Price': 1797,
#    'NumberOfPersons': 3,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Ostseehotel, Wustrow'},
#   {'caseId': 'Journey138',
#    'HolidayType': 'Bathing',
#    'Price': 1044,
#    'NumberOfPersons': 4,
#    'Region': 'BalticSea',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Baltic Sea'},
#   {'caseId': 'Journey139',
#    'HolidayType': 'Bathing',
#    'Price': 639,
#    'NumberOfPersons': 2,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Fehmarn'},
#   {'caseId': 'Journey140',
#    'HolidayType': 'Bathing',
#    'Price': 1818,
#    'NumberOfPersons': 2,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat, Ruegen'},
#   {'caseId': 'Journey141',
#    'HolidayType': 'Recreation',
#    'Price': 539,
#    'NumberOfPersons': 4,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Baltic Sea'},
#   {'caseId': 'Journey142',
#    'HolidayType': 'Recreation',
#    'Price': 709,
#    'NumberOfPersons': 6,
#    'Region': 'BalticSea',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Baltic Sea'},
#   {'caseId': 'Journey143',
#    'HolidayType': 'Active',
#    'Price': 994,
#    'NumberOfPersons': 4,
#    'Region': 'BalticSea',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Baltic Sea'},
#   {'caseId': 'Journey144',
#    'HolidayType': 'Wandering',
#    'Price': 547,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Hirschen, Black Forest'},
#   {'caseId': 'Journey145',
#    'HolidayType': 'Recreation',
#    'Price': 868,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Hirschen, Black Forest'},
#   {'caseId': 'Journey146',
#    'HolidayType': 'Wandering',
#    'Price': 907,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldwinkel, Black Forest'},
#   {'caseId': 'Journey147',
#    'HolidayType': 'Wandering',
#    'Price': 698,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldwinkel, Black Forest'},
#   {'caseId': 'Journey148',
#    'HolidayType': 'Wandering',
#    'Price': 738,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Kandel, Black Forest'},
#   {'caseId': 'Journey149',
#    'HolidayType': 'Recreation',
#    'Price': 922,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Kandel, Black Forest'},
#   {'caseId': 'Journey150',
#    'HolidayType': 'Wandering',
#    'Price': 3732,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Kurhotel, Black Forest'},
#   {'caseId': 'Journey151',
#    'HolidayType': 'Recreation',
#    'Price': 1138,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Kurhotel, Black Forest'},
#   {'caseId': 'Journey152',
#    'HolidayType': 'Wandering',
#    'Price': 449,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey153',
#    'HolidayType': 'Wandering',
#    'Price': 459,
#    'NumberOfPersons': 5,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey154',
#    'HolidayType': 'Wandering',
#    'Price': 1039,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey155',
#    'HolidayType': 'Wandering',
#    'Price': 2538,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey156',
#    'HolidayType': 'Recreation',
#    'Price': 1313,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey157',
#    'HolidayType': 'Recreation',
#    'Price': 904,
#    'NumberOfPersons': 6,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'October',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey158',
#    'HolidayType': 'Recreation',
#    'Price': 984,
#    'NumberOfPersons': 7,
#    'Region': 'BlackForest',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Black Forest'},
#   {'caseId': 'Journey159',
#    'HolidayType': 'Recreation',
#    'Price': 638,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Oberhof, Thuringia'},
#   {'caseId': 'Journey160',
#    'HolidayType': 'Recreation',
#    'Price': 922,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Oberhof, Thuringia'},
#   {'caseId': 'Journey161',
#    'HolidayType': 'Active',
#    'Price': 998,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Finsterbergen, Thuringia'},
#   {'caseId': 'Journey162',
#    'HolidayType': 'Wandering',
#    'Price': 2588,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Finsterbergen, Thuringia'},
#   {'caseId': 'Journey163',
#    'HolidayType': 'Wandering',
#    'Price': 1377,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Train',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Rennsteig, Thuringia'},
#   {'caseId': 'Journey164',
#    'HolidayType': 'Recreation',
#    'Price': 918,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Rennsteig, Thuringia'},
#   {'caseId': 'Journey165',
#    'HolidayType': 'Active',
#    'Price': 2285,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Rennsteig, Thuringia'},
#   {'caseId': 'Journey166',
#    'HolidayType': 'Recreation',
#    'Price': 2668,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'October',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey167',
#    'HolidayType': 'Active',
#    'Price': 1497,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey168',
#    'HolidayType': 'Active',
#    'Price': 2388,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey169',
#    'HolidayType': 'Recreation',
#    'Price': 589,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Thuringia'},
#   {'caseId': 'Journey170',
#    'HolidayType': 'Recreation',
#    'Price': 1128,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Train',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Thuringia'},
#   {'caseId': 'Journey171',
#    'HolidayType': 'Recreation',
#    'Price': 589,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Thuringia'},
#   {'caseId': 'Journey172',
#    'HolidayType': 'Recreation',
#    'Price': 1148,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Thuringia'},
#   {'caseId': 'Journey173',
#    'HolidayType': 'Wandering',
#    'Price': 574,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Thuringia'},
#   {'caseId': 'Journey174',
#    'HolidayType': 'Bathing',
#    'Price': 858,
#    'NumberOfPersons': 4,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'May',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey175',
#    'HolidayType': 'Bathing',
#    'Price': 2078,
#    'NumberOfPersons': 4,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey176',
#    'HolidayType': 'Bathing',
#    'Price': 4718,
#    'NumberOfPersons': 7,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'July',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey177',
#    'HolidayType': 'Bathing',
#    'Price': 1698,
#    'NumberOfPersons': 4,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'August',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey178',
#    'HolidayType': 'Bathing',
#    'Price': 649,
#    'NumberOfPersons': 6,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'September',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey179',
#    'HolidayType': 'Bathing',
#    'Price': 394,
#    'NumberOfPersons': 3,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'June',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Atlantik, France'},
#   {'caseId': 'Journey180',
#    'HolidayType': 'Bathing',
#    'Price': 1289,
#    'NumberOfPersons': 5,
#    'Region': 'Atlantic',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'July',
# ...
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Aparthotel Bocksberg, Harz'},
#   {'caseId': 'Journey943',
#    'HolidayType': 'Skiing',
#    'Price': 2007,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Aparthotel Bocksberg, Harz'},
#   {'caseId': 'Journey944',
#    'HolidayType': 'Recreation',
#    'Price': 2368,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 10,
#    'Season': 'December',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Travelhotel Waldfrieden, Harz'},
#   {'caseId': 'Journey945',
#    'HolidayType': 'Recreation',
#    'Price': 1485,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Travelhotel Waldfrieden, Harz'},
#   {'caseId': 'Journey946',
#    'HolidayType': 'Wandering',
#    'Price': 1298,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Travelhotel Waldfrieden, Harz'},
#   {'caseId': 'Journey947',
#    'HolidayType': 'Active',
#    'Price': 1782,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Travelhotel Waldfrieden, Harz'},
#   {'caseId': 'Journey948',
#    'HolidayType': 'Recreation',
#    'Price': 2007,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Harzquell, Harz'},
#   {'caseId': 'Journey949',
#    'HolidayType': 'Wandering',
#    'Price': 1168,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Harzquell, Harz'},
#   {'caseId': 'Journey950',
#    'HolidayType': 'Skiing',
#    'Price': 1460,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Harzquell, Harz'},
#   {'caseId': 'Journey951',
#    'HolidayType': 'Recreation',
#    'Price': 1522,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#   {'caseId': 'Journey952',
#    'HolidayType': 'Recreation',
#    'Price': 1482,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#   {'caseId': 'Journey953',
#    'HolidayType': 'Skiing',
#    'Price': 1235,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Fuerstenhoeh, Harz'},
#   {'caseId': 'Journey954',
#    'HolidayType': 'Wandering',
#    'Price': 599,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'November',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Panoramic, Harz'},
#   {'caseId': 'Journey955',
#    'HolidayType': 'Recreation',
#    'Price': 679,
#    'NumberOfPersons': 5,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Panoramic, Harz'},
#   {'caseId': 'Journey956',
#    'HolidayType': 'Recreation',
#    'Price': 419,
#    'NumberOfPersons': 2,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Ferienpark, Harz'},
#   {'caseId': 'Journey957',
#    'HolidayType': 'Wandering',
#    'Price': 1114,
#    'NumberOfPersons': 4,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 10,
#    'Season': 'December',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Ferienpark, Harz'},
#   {'caseId': 'Journey958',
#    'HolidayType': 'Skiing',
#    'Price': 324,
#    'NumberOfPersons': 3,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Teichtal, Harz'},
#   {'caseId': 'Journey959',
#    'HolidayType': 'Skiing',
#    'Price': 499,
#    'NumberOfPersons': 6,
#    'Region': 'Harz',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Teichtal, Harz'},
#   {'caseId': 'Journey960',
#    'HolidayType': 'Wandering',
#    'Price': 1227,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Hirschen, Black Forest'},
#   {'caseId': 'Journey961',
#    'HolidayType': 'Active',
#    'Price': 748,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Hirschen, Black Forest'},
#   {'caseId': 'Journey962',
#    'HolidayType': 'Skiing',
#    'Price': 1735,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Treff-Hotel, Black Forest'},
#   {'caseId': 'Journey963',
#    'HolidayType': 'Wandering',
#    'Price': 2768,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'March',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Treff-Hotel, Black Forest'},
#   {'caseId': 'Journey964',
#    'HolidayType': 'Recreation',
#    'Price': 1737,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Kandel, Black Forest'},
#   {'caseId': 'Journey965',
#    'HolidayType': 'Wandering',
#    'Price': 818,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Kandel, Black Forest'},
#   {'caseId': 'Journey966',
#    'HolidayType': 'Recreation',
#    'Price': 2322,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 10,
#    'Season': 'December',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Mummelsee, Black Forest'},
#   {'caseId': 'Journey967',
#    'HolidayType': 'Skiing',
#    'Price': 1158,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Mummelsee, Black Forest'},
#   {'caseId': 'Journey968',
#    'HolidayType': 'Active',
#    'Price': 1008,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldwinkel, Black Forest'},
#   {'caseId': 'Journey969',
#    'HolidayType': 'Recreation',
#    'Price': 1260,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Waldwinkel, Black Forest'},
#   {'caseId': 'Journey970',
#    'HolidayType': 'Wandering',
#    'Price': 1257,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Gasthof Hochkopfhaus, Black Forest'},
#   {'caseId': 'Journey971',
#    'HolidayType': 'Skiing',
#    'Price': 838,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Gasthof Hochkopfhaus, Black Forest'},
#   {'caseId': 'Journey972',
#    'HolidayType': 'Recreation',
#    'Price': 897,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Landgasthof Schuetzen, Black Forest'},
#   {'caseId': 'Journey973',
#    'HolidayType': 'Wandering',
#    'Price': 688,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 6,
#    'Season': 'December',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Landgasthof Schuetzen, Black Forest'},
#   {'caseId': 'Journey974',
#    'HolidayType': 'Active',
#    'Price': 454,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Ferienpark Black Forest'},
#   {'caseId': 'Journey975',
#    'HolidayType': 'Active',
#    'Price': 514,
#    'NumberOfPersons': 6,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Ferienpark Black Forest'},
#   {'caseId': 'Journey976',
#    'HolidayType': 'Recreation',
#    'Price': 459,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwarzwaldgrund'},
#   {'caseId': 'Journey977',
#    'HolidayType': 'Recreation',
#    'Price': 1068,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwarzwaldgrund'},
#   {'caseId': 'Journey978',
#    'HolidayType': 'Skiing',
#    'Price': 549,
#    'NumberOfPersons': 6,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Sonnenrain, Black Forest'},
#   {'caseId': 'Journey979',
#    'HolidayType': 'Recreation',
#    'Price': 679,
#    'NumberOfPersons': 2,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwarzwaldblick'},
#   {'caseId': 'Journey980',
#    'HolidayType': 'Recreation',
#    'Price': 599,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwarzwaldblick'},
#   {'caseId': 'Journey981',
#    'HolidayType': 'Skiing',
#    'Price': 464,
#    'NumberOfPersons': 3,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwiezer Hof, Black Forest'},
#   {'caseId': 'Journey982',
#    'HolidayType': 'Wandering',
#    'Price': 1033,
#    'NumberOfPersons': 5,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'March',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schwiezer Hof, Black Forest'},
#   {'caseId': 'Journey983',
#    'HolidayType': 'Recreation',
#    'Price': 989,
#    'NumberOfPersons': 4,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Panorama-Blick, Black Forest'},
#   {'caseId': 'Journey984',
#    'HolidayType': 'Wandering',
#    'Price': 839,
#    'NumberOfPersons': 6,
#    'Region': 'BlackForest',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Panorama-Blick, Black Forest'},
#   {'caseId': 'Journey985',
#    'HolidayType': 'Wandering',
#    'Price': 1672,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Friedrichroda, Thuringia'},
#   {'caseId': 'Journey986',
#    'HolidayType': 'Recreation',
#    'Price': 1178,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Friedrichroda, Thuringia'},
#   {'caseId': 'Journey987',
#    'HolidayType': 'Active',
#    'Price': 4092,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'February',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Finsterbergen, Thuringia'},
#   {'caseId': 'Journey988',
#    'HolidayType': 'Wandering',
#    'Price': 1368,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Hotel Finsterbergen, Thuringia'},
#   {'caseId': 'Journey989',
#    'HolidayType': 'Wandering',
#    'Price': 1104,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Schoene Aussicht, Thuringia'},
#   {'caseId': 'Journey990',
#    'HolidayType': 'Skiing',
#    'Price': 883,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Schoene Aussicht, Thuringia'},
#   {'caseId': 'Journey991',
#    'HolidayType': 'Recreation',
#    'Price': 688,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Oberhof, Thuringia'},
#   {'caseId': 'Journey992',
#    'HolidayType': 'Wandering',
#    'Price': 1773,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'November',
#    'Accomodation': 'ThreeStars',
#    'Hotel': 'Berghotel Oberhof, Thuringia'},
#   {'caseId': 'Journey993',
#    'HolidayType': 'Wandering',
#    'Price': 1138,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'January',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey994',
#    'HolidayType': 'Recreation',
#    'Price': 1647,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey995',
#    'HolidayType': 'Skiing',
#    'Price': 1977,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'FourStars',
#    'Hotel': 'Hotel Panorama, Thuringia'},
#   {'caseId': 'Journey996',
#    'HolidayType': 'Wandering',
#    'Price': 1294,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 14,
#    'Season': 'January',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Am Schuetzenberg, Thuringia'},
#   {'caseId': 'Journey997',
#    'HolidayType': 'Recreation',
#    'Price': 785,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'December',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Am Schuetzenberg, Thuringia'},
#   {'caseId': 'Journey998',
#    'HolidayType': 'Active',
#    'Price': 987,
#    'NumberOfPersons': 4,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Frankenwald, Thuringia'},
#   {'caseId': 'Journey999',
#    'HolidayType': 'Wandering',
#    'Price': 598,
#    'NumberOfPersons': 2,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'March',
#    'Accomodation': 'TwoStars',
#    'Hotel': 'Hotel Frankenwald, Thuringia'},
#   {'caseId': 'Journey1000',
#    'HolidayType': 'Wandering',
#    'Price': 389,
#    'NumberOfPersons': 3,
#    'Region': 'Thuringia',
#    'Transportation': 'Car',
#    'Duration': 7,
#    'Season': 'February',
#    'Accomodation': 'HolidayFlat',
#    'Hotel': 'H.Flat Schmeheim, Thuringia'},
#   ...]}

# %%
with open("./travel/travel.json", "w") as fp:
    json.dump(dataFile, fp)

# %%
itemIds = [item["caseId"] for item in content ]
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
localSimFunctions = [ dict(attName="HolidayType", localSimFunction=EqualSim(), weight=1/6), 
                      dict(attName="NumberOfPersons", localSimFunction=RangeSimilarity(1,12), weight=1/6),
                      dict(attName="Region", localSimFunction=EqualSim(), weight=1/6),
                      dict(attName="Transportation", localSimFunction=EqualSim(), weight=1/6),
                      dict(attName="Duration", localSimFunction=RangeSimilarity(3,21), weight=1/6),
                      dict(attName="Season", localSimFunction=NominalRangeSimilarity(months), weight=1/6)]

simDescription = dict(
    globalSim= dict(
        simFunction="Weighted average"
    ),
    localSim = dict(
        HolidayType = dict(
            simFunction = "equals",
            weight = 1/6
        ),
        NumberOfPersons = dict(
            simFunction = "RangeSimilarity",
            weight = 1/6
        ),
        Region = dict(
            simFunction = "equals",
            weight = 1/6
        ),
        Transportation = dict(
            simFunction = "equals",
            weight = 1/6
        ),
        Duration = dict(
            simFunction = "RangeSimilarity",
            weight = 1/6
        ),
        Season = dict(
            simFunction = "NominalRangeSimilarity",
            weight = 1/6,
            description = "Similarity between months in range [January...December]"
        )
    )
)

dataFile = computeSimilarity(simDescription, content, "caseId", itemIds, localSimFunctions, weightedAverage)
with open("./travel/allAttributes.json", "w") as fp:
    json.dump(dataFile, fp,  indent=2)

# %%
class CircularRangeSimilarity(RangeSimilarity):
    def __init__(self, listNominalValues):
        self.values = listNominalValues
        super().__init__(0, len(listNominalValues)-1)
    def compute(self,v1, v2):
        if (v1 in self.values) and (v2 in self.values):
            indexV1 = self.values.index(v1)
            indexV2 = self.values.index(v2)
            
            return super().compute(indexV1, indexV2)
        else:
            return 0.0
